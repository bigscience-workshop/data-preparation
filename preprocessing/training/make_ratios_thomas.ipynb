# %%
import csv

meta_table = []

with open('meta_table.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        meta_table += [row]

lang_to_sizes = {}
orig_lang = {}

for name, size_str, _, _, lang in meta_table[1:]:
    # Manually handle chinese
    if lang in ["zh-TW", "zh-HK", "zht", "zh-tw"]:
        orig_lang[name] = lang
        lang = "zht"
    if lang in ["zh", "zhs", "zh-CN", "zh-cn"]:
        orig_lang[name] = lang
        lang = "zhs"
    if lang.startswith('zh') and lang not in ["zhs", "zht"]:
        raise ValueError(f"Chinese language needs to be either zhs or zht. Got {lang}")
    
    # Skip nigercongo as it was agregated in a single dataset.
    if lang.startswith("nigercongo"):
        continue

    if name in [
        "s2orc",
        "the_pile_enron_emails",
        "twitter_covid19_indonesia_sentiment_analysis",
        "lot_of_indic_tweets",
        "the_pile_stack_exchange",
        "multilingual_knowledge_questions_answers",
        "a_million_news_headlines_abc_australia",  # pseudocrawl
        "india_news_headlines_dataset",
    ]:
        continue

    if name == "opus100" and lang in [
        "en",
        "zh",
        "fr",
        "es",
    ]:
        continue

    size = int(size_str)
    if size > 0:
        lang_to_sizes[lang] = lang_to_sizes.get(lang, []) + [(name, size)]

lang_to_sizes["ar"] += [
    ("pseudocrawl-filtered_595_mawdoo3_com", int(2.2e9)),
]
lang_to_sizes["en"] += [
    ("s2orc_ai2_pdf_parses", int(273e9)),
    ('pseudocrawl-filtered_689_www_abc_net_au', 2.80e9),
    ('pseudocrawl-filtered_510_timesofindia_indiatimes_com', 2.14e9),
    ('pseudocrawl-filtered_497_www_straitstimes_com', 1.39e9),
    ('pseudocrawl-filtered_534_www_nairaland_com', 0.23e9),
    ('pseudocrawl-filtered_638_globalvoices_org', 0.74e9),
    ('pseudocrawl-filtered_498_www_channelnewsasia_com', 0.51e9),
    ('pseudocrawl-filtered_339_www_actasanitaria_com', 0.05e9),
    ('pseudocrawl-filtered_304_www_semana_com', 0.43e9),
    ('pseudocrawl-filtered_501_theindependent_sg', 0.32e9),
    ('pseudocrawl-filtered_159_www_postcrescent_com', 0.23e9),
    ('pseudocrawl-filtered_487_thesmartlocal_com', 0.23e9),
    ('pseudocrawl-filtered_696_www_oercommons_org', 0.14e9),
    ('pseudocrawl-filtered_470_forums_hardwarezone_com_sg', 0.14e9),
    ('pseudocrawl-filtered_395_www_evwind_es', 0.15e9),
    ('pseudocrawl-filtered_548_remezcla_com', 0.13e9),
    ('pseudocrawl-filtered_485_blog_moneysmart_sg', 0.12e9),
    ('pseudocrawl-filtered_619_www_qut_edu_au', 0.09e9),
    ('pseudocrawl-filtered_499_www_today_com_news', 0.11e9),
    ('pseudocrawl-filtered_492_www_vivawoman_net', 0.11e9),
    ('pseudocrawl-filtered_483_alvinology_com', 0.08e9),
    ('pseudocrawl-filtered_502_www_ricemedia_co', 0.08e9),
    ('pseudocrawl-filtered_488_dailyvanity_sg', 0.05e9),
    ('pseudocrawl-filtered_500_www_asiaone_com_singapore', 0.06e9),
]
lang_to_sizes["es"] += [
    ('pseudocrawl-filtered_100_www_aporrea_org', 3.44e9),
    ('pseudocrawl-filtered_396_www_eldiario_es', 2.99e9),
    ('pseudocrawl-filtered_341_es_cointelegraph_com', 2.74e9),
    ('pseudocrawl-filtered_20_www_clarin_com', 2.65e9),
    ('pseudocrawl-filtered_424_www_lavanguardia_com', 2.19e9),
    ('pseudocrawl-filtered_63_www_lanacion_com_ar', 2.15e9),
    ('pseudocrawl-filtered_255_elcomercio_pe', 1.97e9),
    ('pseudocrawl-filtered_333_www_elmundo_es', 1.83e9),
    ('pseudocrawl-filtered_349_www_eltiempo_com', 1.76e9),
    ('pseudocrawl-filtered_211_www_elcomercio_com', 1.60e9),
    ('pseudocrawl-filtered_267_www_elperiodico_com_es', 1.55e9),
    ('pseudocrawl-filtered_198_www_eleconomista_es', 1.39e9),
    ('pseudocrawl-filtered_181_noticiassin_com', 1.46e9),
    ('pseudocrawl-filtered_409_www_proceso_com_mx', 1.39e9),
    ('pseudocrawl-filtered_354_www_lagaceta_com_ar', 1.44e9),
    ('pseudocrawl-filtered_263_www_lasexta_com', 1.40e9),
    ('pseudocrawl-filtered_641_es_globalvoices_org', 0.82e9),
    ('pseudocrawl-filtered_146_www_perfil_com', 1.31e9),
    ('pseudocrawl-filtered_215_www_lainformacion_com', 1.38e9),
    ('pseudocrawl-filtered_518_www_elcolombiano_com', 1.02e9),
    ('pseudocrawl-filtered_189_www_eleconomista_com_mx', 1.24e9),
    ('pseudocrawl-filtered_429_cadenaser_com', 1.30e9),
    ('pseudocrawl-filtered_103_www_elmostrador_cl', 1.21e9),
    ('pseudocrawl-filtered_237_www_cronista_com', 0.94e9),
    ('pseudocrawl-filtered_248_www_telesurtv_net', 1.02e9),
    ('pseudocrawl-filtered_136_valenciaplaza_com', 1.04e9),
    ('pseudocrawl-filtered_245_www_noticiasdenavarra_com', 0.94e9),
    ('pseudocrawl-filtered_71_www_rtve_es', 0.66e9),
    ('pseudocrawl-filtered_229_www_expansion_com', 0.50e9),
    ('pseudocrawl-filtered_58_www_levante_emv_com', 0.85e9),
    ('pseudocrawl-filtered_157_www_elsoldemexico_com_mx', 0.89e9),
    ('pseudocrawl-filtered_299_www_lne_es', 0.81e9),
    ('pseudocrawl-filtered_79_www_laopiniondemurcia_es', 0.78e9),
    ('pseudocrawl-filtered_67_www_elpais_cr', 0.63e9),
    ('pseudocrawl-filtered_86_www_motorpasion_com', 0.71e9),
    ('pseudocrawl-filtered_373_www_farodevigo_es', 0.71e9),
    ('pseudocrawl-filtered_249_www_telecinco_es', 0.75e9),
    ('pseudocrawl-filtered_287_www_cibercuba_com', 0.73e9),
    ('pseudocrawl-filtered_288_www_marca_com', 0.65e9),
    ('pseudocrawl-filtered_675_www_elespectador_com', 0.59e9),
    ('pseudocrawl-filtered_213_www_hola_com', 0.61e9),
    ('pseudocrawl-filtered_209_misionesonline_net', 0.67e9),
    ('pseudocrawl-filtered_430_www_eldiario_ec', 0.64e9),
    ('pseudocrawl-filtered_381_www_cuartopoder_es', 0.66e9),
    ('pseudocrawl-filtered_324_gestion_pe', 0.64e9),
    ('pseudocrawl-filtered_203_www_que_es', 0.62e9),
    ('pseudocrawl-filtered_226_www_ole_com_ar', 0.55e9),
    ('pseudocrawl-filtered_405_www_emol_com', 0.62e9),
    ('pseudocrawl-filtered_90_peru_com', 0.47e9),
    ('pseudocrawl-filtered_257_www_diaridetarragona_com', 0.59e9),
    ('pseudocrawl-filtered_392_www_muypymes_com', 0.45e9),
    ('pseudocrawl-filtered_317_diariocorreo_pe', 0.55e9),
    ('pseudocrawl-filtered_253_www_debate_com_mx', 0.50e9),
    ('pseudocrawl-filtered_359_www_efeverde_com', 0.54e9),
    ('pseudocrawl-filtered_28_www_fayerwayer_com', 0.52e9),
    ('pseudocrawl-filtered_78_www_listindiario_com', 0.53e9),
    ('pseudocrawl-filtered_256_www_laprovincia_es', 0.54e9),
    ('pseudocrawl-filtered_232_tn_com_ar', 0.48e9),
    ('pseudocrawl-filtered_165_www_ticbeat_com', 0.55e9),
    ('pseudocrawl-filtered_401_www_elperiodicodemexico_com', 0.55e9),
    ('pseudocrawl-filtered_277_www_entornointeligente_com', 0.36e9),
    ('pseudocrawl-filtered_130_www_elperiodicomediterraneo_com', 0.49e9),
    ('pseudocrawl-filtered_44_ladiaria_com_uy', 0.48e9),
    ('pseudocrawl-filtered_220_www_vanguardia_com_mx', 0.48e9),
    ('pseudocrawl-filtered_376_www_elpopular_com_ar', 0.49e9),
    ('pseudocrawl-filtered_169_www_el_carabobeno_com', 0.45e9),
    ('pseudocrawl-filtered_315_lasillavacia_com', 0.42e9),
    ('pseudocrawl-filtered_320_www_paginasiete_bo', 0.46e9),
    ('pseudocrawl-filtered_422_www_formulatv_com', 0.31e9),
    ('pseudocrawl-filtered_116_www_latribuna_hn', 0.37e9),
    ('pseudocrawl-filtered_431_www_elperiodicoextremadura_com', 0.42e9),
    ('pseudocrawl-filtered_91_www_diario26_com', 0.43e9),
    ('pseudocrawl-filtered_325_www_laprensa_hn', 0.34e9),
    ('pseudocrawl-filtered_53_www_expreso_ec', 0.39e9),
    ('pseudocrawl-filtered_207_elimpulso_com', 0.24e9),
    ('pseudocrawl-filtered_404_www_telam_com_ar', 0.39e9),
    ('pseudocrawl-filtered_276_radio_uchile_cl', 0.32e9),
    ('pseudocrawl-filtered_172_www_rionegro_com_ar', 0.36e9),
    ('pseudocrawl-filtered_167_www_ambientum_com', 0.36e9),
    ('pseudocrawl-filtered_21_www_elperiodicodearagon_com', 0.36e9),
    ('pseudocrawl-filtered_250_www_cooperativa_cl', 0.34e9),
    ('pseudocrawl-filtered_34_www_losandes_com_ar', 0.35e9),
    ('pseudocrawl-filtered_231_ojo_pe', 0.32e9),
    ('pseudocrawl-filtered_417_www_radiolaprimerisima_com', 0.31e9),
    ('pseudocrawl-filtered_246_www_eldiarionuevodia_com_ar', 0.34e9),
    ('pseudocrawl-filtered_406_www_americaeconomia_com', 0.31e9),
    ('pseudocrawl-filtered_125_www_noticiasde_es', 0.24e9),
    ('pseudocrawl-filtered_223_www_eltambor_es', 0.33e9),
    ('pseudocrawl-filtered_23_www_elconfidencialdigital_com', 0.30e9),
    ('pseudocrawl-filtered_286_www_nacion_com', 0.30e9),
    ('pseudocrawl-filtered_182_correodelsur_com', 0.26e9),
    ('pseudocrawl-filtered_367_elcorreoweb_es', 0.31e9),
    ('pseudocrawl-filtered_118_www_elheraldo_hn', 0.27e9),
    ('pseudocrawl-filtered_294_www_laopinion_com_co', 0.28e9),
    ('pseudocrawl-filtered_386_www_prensalibre_com', 0.27e9),
    ('pseudocrawl-filtered_233_www_dinero_com', 0.27e9),
    ('pseudocrawl-filtered_254_diario_mx', 0.27e9),
    ('pseudocrawl-filtered_374_www_talcualdigital_com', 0.25e9),
    ('pseudocrawl-filtered_219_www_aguasresiduales_info', 0.23e9),
    ('pseudocrawl-filtered_420_www_retema_es', 0.24e9),
    ('pseudocrawl-filtered_244_www_df_cl', 0.20e9),
    ('pseudocrawl-filtered_32_www_elexpresso_com', 0.21e9),
    ('pseudocrawl-filtered_153_financialfood_es', 0.23e9),
    ('pseudocrawl-filtered_158_www_diariodeleon_es', 0.22e9),
    ('pseudocrawl-filtered_56_www_eluniverso_com', 0.23e9),
    ('pseudocrawl-filtered_62_www_lapagina_com_sv', 0.20e9),
    ('pseudocrawl-filtered_280_salamancartvaldia_es', 0.20e9),
    ('pseudocrawl-filtered_30_www_radiocable_com', 0.21e9),
]
lang_to_sizes["eu"] += [
    ('pseudocrawl-filtered_635_www_berria_eus', 0.23e9),
    ('pseudocrawl-filtered_637_www_argia_eus', 0.15e9),
    ('pseudocrawl-filtered_506_goiena_eus', 0.11e9),
    ('pseudocrawl-filtered_563_ahotsak_eus', 0.08e9),
]
lang_to_sizes["fr"] += [
    ("hal_archives_ouvertes", int(87e9)),
    ("pseudocrawl-filtered_550_www_lemonde_fr", int(5e9)),
    ("pseudocrawl-filtered_530_www_mediapart_fr", int(0.8e9)),
    ("pseudocrawl-filtered_599_fr_globalvoices_org", int(0.5e9)),
]
lang_to_sizes["id"] += [
    ('pseudocrawl-filtered_549_www_cnnindonesia_com', 0.54e9),
    ('pseudocrawl-filtered_572_tirto_id', 0.62e9),
    ('pseudocrawl-filtered_545_www_detik_com', 0.31e9),
    ('pseudocrawl-filtered_512_kumparan_com', 0.21e9),
]
lang_to_sizes["indic-hi"] += [
    ('pseudocrawl-filtered_667_www_bhaskar_com', 1.45e9),
    ('pseudocrawl-filtered_515_www_aajtak_in', 0.49e9),
]
lang_to_sizes["pt"] += [
    ('pseudocrawl-filtered_672_pt_globalvoices_org', 0.22e9),
]
lang_to_sizes["zhs"] += [
    ('pseudocrawl-filtered_503_www_zaobao_com_sg', 0.28e9),
    ('pseudocrawl-filtered_674_ai_baidu_com', 0.06e9),
]


nigercongo_sizes = [
    ('sw', 264036370),
    ('yo', 70039249),
    ('rw', 42145941),
    ('xh', 14467934),
    ('ig', 12520386),
    ('zu', 8959591),
    ('sn', 7489361),
    ('lg', 4538572),
    ('wo', 3526807),
    ('rn', 3216020),
    ('fon', 1973909),
    ('nso', 1932754),
    ('ln', 1631248),
    ('tn', 1533108),
    ('tw', 1241938),
    ('ny', 1194349),
    ('st', 754055),
    ('ts', 725380),
    ('ak', 670157),
    ('bm', 385450),
    ('ki', 362345),
    ('tum', 179586),
]

for ln, ct in nigercongo_sizes:
    lang_to_sizes[f"nigercongo-{ln}"] = [(f"aggregated", ct)]

for lang in lang_to_sizes:
    lang_to_sizes[lang] = sorted(lang_to_sizes[lang], key=lambda x:x[1], reverse=True)
    
lang_to_sizes
# Out:
# {'ar': [('openiti', 17401602240),
#   ('arabic_billion_words', 16870246181),
#   ('openiti_proc', 14213998620),
#   ('uncorpus', 5173513262),
#   ('open_subtitles', 3691899354),
#   ('wikipedia', 2924624512),
#   ('multi_un_2', 2670175122),
#   ('pseudocrawl-filtered_595_mawdoo3_com', 2200000000),
#   ('wikisource_filtered', 1256182810),
#   ('tashkeela', 1081110237),
#   ('sanad', 581959127),
#   ('ksucca', 460038217),
#   ('brad_2', 396674847),
#   ('osac', 238021605),
#   ('kalimat', 94725838),
#   ('ted_talks_iwslt', 93467133),
#   ('opus100', 92706048),
#   ('wiktionary_filtered', 56547744),
#   ('labr', 38192464),
#   ('wikinews_filtered', 37951837),
#   ('habibi', 30257750),
#   ('wikibooks_filtered', 14120300),
#   ('wikiquote_filtered', 12225315),
#   ('qedcorpus', 10622059),
#   ('arabench', 7837368),
#   ('wikiversity_filtered', 5353500)],
#  'ca': [('catalan_textual_corpus', 10890745832),
#   ('catalan_general_crawling', 2689414189),
#   ('wikipedia', 1822564157),
#   ('tecla', 322436076),
#   ('catalan_government_crawling', 258227474),
#   ('wiktionary_filtered', 215759641),
#   ('wikisource_filtered', 92830936),
#   ('ca_text_corpus', 81543301),
#   ('parlament_parla', 54018089),
#   ('opus100', 45720300),
#   ('tv3_parla', 25104846),
#   ('open_subtitles', 20400087),
#   ('wikinews_filtered', 16730924),
#   ('wikibooks_filtered', 13248006),
#   ('ted_talks_iwslt', 10341494),
#   ('wikiquote_filtered', 10226823),
#   ('teca', 4280947),
#   ('enriched_conllu_ancora_for_ml_training', 2838436),
#   ('wikimedia_filtered', 2789807),
#   ('viquiquad', 2551354),
#   ('vilaquad', 2415762),
#   ('sts_ca', 718804),
#   ('xquad_ca', 216096)],
#  'en': [('s2orc_ai2_pdf_parses', 273000000000),
#   ('arxiv', 191182889759),
#   ('pmc', 118838497327),
#   ('s2orc_ai2_abstracts', 117717603689),
#   ('the_pile_uspto', 24989825244),
#   ('project_gutenberg', 18787969556),
#   ('open_subtitles', 13583312431),
#   ('wikipedia', 9988396576),
#   ('no_code_stackexchange', 5833262267),
#   ('uncorpus', 4558764839),
#   ('wiktionary_filtered', 3813930779),
#   ('pseudocrawl-filtered_689_www_abc_net_au', 2800000000.0),
#   ('multi_un_2', 2564843307),
#   ('pseudocrawl-filtered_510_timesofindia_indiatimes_com', 2140000000.0),
#   ('pseudocrawl-filtered_497_www_straitstimes_com', 1390000000.0),
#   ('pseudocrawl-filtered_638_globalvoices_org', 740000000.0),
#   ('wikibooks_filtered', 697765105),
#   ('pseudocrawl-filtered_498_www_channelnewsasia_com', 510000000.0),
#   ('pseudocrawl-filtered_304_www_semana_com', 430000000.0),
#   ('wikiquote_filtered', 403936398),
#   ('royal_society_corpus', 403726752),
#   ('the_pile_europarl', 334596910),
#   ('pseudocrawl-filtered_501_theindependent_sg', 320000000.0),
#   ('wikiversity_filtered', 306014462),
#   ('wikivoyage_filtered', 266807036),
#   ('pseudocrawl-filtered_534_www_nairaland_com', 230000000.0),
#   ('pseudocrawl-filtered_159_www_postcrescent_com', 230000000.0),
#   ('pseudocrawl-filtered_487_thesmartlocal_com', 230000000.0),
#   ('pseudocrawl-filtered_395_www_evwind_es', 150000000.0),
#   ('pseudocrawl-filtered_696_www_oercommons_org', 140000000.0),
#   ('pseudocrawl-filtered_470_forums_hardwarezone_com_sg', 140000000.0),
#   ('qedcorpus', 138560357),
#   ('pseudocrawl-filtered_548_remezcla_com', 130000000.0),
#   ('pseudocrawl-filtered_485_blog_moneysmart_sg', 120000000.0),
#   ('pseudocrawl-filtered_499_www_today_com_news', 110000000.0),
#   ('pseudocrawl-filtered_492_www_vivawoman_net', 110000000.0),
#   ('pseudocrawl-filtered_619_www_qut_edu_au', 90000000.0),
#   ('wikinews_filtered', 83983930),
#   ('pseudocrawl-filtered_483_alvinology_com', 80000000.0),
#   ('pseudocrawl-filtered_502_www_ricemedia_co', 80000000.0),
#   ('ted_talks_iwslt', 65511039),
#   ('pseudocrawl-filtered_500_www_asiaone_com_singapore', 60000000.0),
#   ('pseudocrawl-filtered_339_www_actasanitaria_com', 50000000.0),
#   ('pseudocrawl-filtered_488_dailyvanity_sg', 50000000.0),
#   ('bloom', 12740152),
#   ('odiencorp', 8476701),
#   ('scielo', 2785526),
#   ('book_dash_books', 88070)],
#  'es': [('open_subtitles', 7065199992),
#   ('uncorpus', 4646021096),
#   ('pseudocrawl-filtered_100_www_aporrea_org', 3440000000.0),
#   ('pseudocrawl-filtered_396_www_eldiario_es', 2990000000.0),
#   ('pseudocrawl-filtered_341_es_cointelegraph_com', 2740000000.0),
#   ('wikipedia', 2716315229),
#   ('pseudocrawl-filtered_20_www_clarin_com', 2650000000.0),
#   ('multi_un_2', 2297718298),
#   ('pseudocrawl-filtered_424_www_lavanguardia_com', 2190000000.0),
#   ('pseudocrawl-filtered_63_www_lanacion_com_ar', 2150000000.0),
#   ('pseudocrawl-filtered_255_elcomercio_pe', 1970000000.0),
#   ('pseudocrawl-filtered_333_www_elmundo_es', 1830000000.0),
#   ('pseudocrawl-filtered_349_www_eltiempo_com', 1760000000.0),
#   ('pseudocrawl-filtered_211_www_elcomercio_com', 1600000000.0),
#   ('pseudocrawl-filtered_267_www_elperiodico_com_es', 1550000000.0),
#   ('pseudocrawl-filtered_181_noticiassin_com', 1460000000.0),
#   ('pseudocrawl-filtered_354_www_lagaceta_com_ar', 1440000000.0),
#   ('pseudocrawl-filtered_263_www_lasexta_com', 1400000000.0),
#   ('pseudocrawl-filtered_198_www_eleconomista_es', 1390000000.0),
#   ('pseudocrawl-filtered_409_www_proceso_com_mx', 1390000000.0),
#   ('pseudocrawl-filtered_215_www_lainformacion_com', 1380000000.0),
#   ('pseudocrawl-filtered_146_www_perfil_com', 1310000000.0),
#   ('pseudocrawl-filtered_429_cadenaser_com', 1300000000.0),
#   ('pseudocrawl-filtered_189_www_eleconomista_com_mx', 1240000000.0),
#   ('pseudocrawl-filtered_103_www_elmostrador_cl', 1210000000.0),
#   ('pseudocrawl-filtered_136_valenciaplaza_com', 1040000000.0),
#   ('wikisource_filtered', 1038681167),
#   ('pseudocrawl-filtered_518_www_elcolombiano_com', 1020000000.0),
#   ('pseudocrawl-filtered_248_www_telesurtv_net', 1020000000.0),
#   ('pseudocrawl-filtered_237_www_cronista_com', 940000000.0),
#   ('pseudocrawl-filtered_245_www_noticiasdenavarra_com', 940000000.0),
#   ('pseudocrawl-filtered_157_www_elsoldemexico_com_mx', 890000000.0),
#   ('pseudocrawl-filtered_58_www_levante_emv_com', 850000000.0),
#   ('pseudocrawl-filtered_641_es_globalvoices_org', 820000000.0),
#   ('pseudocrawl-filtered_299_www_lne_es', 810000000.0),
#   ('pseudocrawl-filtered_79_www_laopiniondemurcia_es', 780000000.0),
#   ('pseudocrawl-filtered_249_www_telecinco_es', 750000000.0),
#   ('pseudocrawl-filtered_287_www_cibercuba_com', 730000000.0),
#   ('pseudocrawl-filtered_86_www_motorpasion_com', 710000000.0),
#   ('pseudocrawl-filtered_373_www_farodevigo_es', 710000000.0),
#   ('pseudocrawl-filtered_209_misionesonline_net', 670000000.0),
#   ('pseudocrawl-filtered_71_www_rtve_es', 660000000.0),
#   ('pseudocrawl-filtered_381_www_cuartopoder_es', 660000000.0),
#   ('pseudocrawl-filtered_288_www_marca_com', 650000000.0),
#   ('pseudocrawl-filtered_430_www_eldiario_ec', 640000000.0),
#   ('pseudocrawl-filtered_324_gestion_pe', 640000000.0),
#   ('pseudocrawl-filtered_67_www_elpais_cr', 630000000.0),
#   ('pseudocrawl-filtered_203_www_que_es', 620000000.0),
#   ('pseudocrawl-filtered_405_www_emol_com', 620000000.0),
#   ('pseudocrawl-filtered_213_www_hola_com', 610000000.0),
#   ('pseudocrawl-filtered_675_www_elespectador_com', 590000000.0),
#   ('pseudocrawl-filtered_257_www_diaridetarragona_com', 590000000.0),
#   ('pseudocrawl-filtered_226_www_ole_com_ar', 550000000.0),
#   ('pseudocrawl-filtered_317_diariocorreo_pe', 550000000.0),
#   ('pseudocrawl-filtered_165_www_ticbeat_com', 550000000.0),
#   ('pseudocrawl-filtered_401_www_elperiodicodemexico_com', 550000000.0),
#   ('pseudocrawl-filtered_359_www_efeverde_com', 540000000.0),
#   ('pseudocrawl-filtered_256_www_laprovincia_es', 540000000.0),
#   ('pseudocrawl-filtered_78_www_listindiario_com', 530000000.0),
#   ('pseudocrawl-filtered_28_www_fayerwayer_com', 520000000.0),
#   ('pseudocrawl-filtered_229_www_expansion_com', 500000000.0),
#   ('pseudocrawl-filtered_253_www_debate_com_mx', 500000000.0),
#   ('pseudocrawl-filtered_130_www_elperiodicomediterraneo_com', 490000000.0),
#   ('pseudocrawl-filtered_376_www_elpopular_com_ar', 490000000.0),
#   ('pseudocrawl-filtered_232_tn_com_ar', 480000000.0),
#   ('pseudocrawl-filtered_44_ladiaria_com_uy', 480000000.0),
#   ('pseudocrawl-filtered_220_www_vanguardia_com_mx', 480000000.0),
#   ('wiktionary_filtered', 472171328),
#   ('pseudocrawl-filtered_90_peru_com', 470000000.0),
#   ('pseudocrawl-filtered_320_www_paginasiete_bo', 460000000.0),
#   ('pseudocrawl-filtered_392_www_muypymes_com', 450000000.0),
#   ('pseudocrawl-filtered_169_www_el_carabobeno_com', 450000000.0),
#   ('pseudocrawl-filtered_91_www_diario26_com', 430000000.0),
#   ('pseudocrawl-filtered_315_lasillavacia_com', 420000000.0),
#   ('pseudocrawl-filtered_431_www_elperiodicoextremadura_com', 420000000.0),
#   ('pseudocrawl-filtered_53_www_expreso_ec', 390000000.0),
#   ('pseudocrawl-filtered_404_www_telam_com_ar', 390000000.0),
#   ('pseudocrawl-filtered_116_www_latribuna_hn', 370000000.0),
#   ('pseudocrawl-filtered_277_www_entornointeligente_com', 360000000.0),
#   ('pseudocrawl-filtered_172_www_rionegro_com_ar', 360000000.0),
#   ('pseudocrawl-filtered_167_www_ambientum_com', 360000000.0),
#   ('pseudocrawl-filtered_21_www_elperiodicodearagon_com', 360000000.0),
#   ('the_pile_europarl', 355996076),
#   ('pseudocrawl-filtered_34_www_losandes_com_ar', 350000000.0),
#   ('pseudocrawl-filtered_325_www_laprensa_hn', 340000000.0),
#   ('pseudocrawl-filtered_250_www_cooperativa_cl', 340000000.0),
#   ('pseudocrawl-filtered_246_www_eldiarionuevodia_com_ar', 340000000.0),
#   ('pseudocrawl-filtered_223_www_eltambor_es', 330000000.0),
#   ('pseudocrawl-filtered_276_radio_uchile_cl', 320000000.0),
#   ('pseudocrawl-filtered_231_ojo_pe', 320000000.0),
#   ('pseudocrawl-filtered_422_www_formulatv_com', 310000000.0),
#   ('pseudocrawl-filtered_417_www_radiolaprimerisima_com', 310000000.0),
#   ('pseudocrawl-filtered_406_www_americaeconomia_com', 310000000.0),
#   ('pseudocrawl-filtered_367_elcorreoweb_es', 310000000.0),
#   ('pseudocrawl-filtered_23_www_elconfidencialdigital_com', 300000000.0),
#   ('pseudocrawl-filtered_286_www_nacion_com', 300000000.0),
#   ('project_gutenberg', 289707919),
#   ('pseudocrawl-filtered_294_www_laopinion_com_co', 280000000.0),
#   ('pseudocrawl-filtered_118_www_elheraldo_hn', 270000000.0),
#   ('pseudocrawl-filtered_386_www_prensalibre_com', 270000000.0),
#   ('pseudocrawl-filtered_233_www_dinero_com', 270000000.0),
#   ('pseudocrawl-filtered_254_diario_mx', 270000000.0),
#   ('pseudocrawl-filtered_182_correodelsur_com', 260000000.0),
#   ('pseudocrawl-filtered_374_www_talcualdigital_com', 250000000.0),
#   ('pseudocrawl-filtered_207_elimpulso_com', 240000000.0),
#   ('pseudocrawl-filtered_125_www_noticiasde_es', 240000000.0),
#   ('pseudocrawl-filtered_420_www_retema_es', 240000000.0),
#   ('pseudocrawl-filtered_219_www_aguasresiduales_info', 230000000.0),
#   ('pseudocrawl-filtered_153_financialfood_es', 230000000.0),
#   ('pseudocrawl-filtered_56_www_eluniverso_com', 230000000.0),
#   ('pseudocrawl-filtered_158_www_diariodeleon_es', 220000000.0),
#   ('pseudocrawl-filtered_32_www_elexpresso_com', 210000000.0),
#   ('pseudocrawl-filtered_30_www_radiocable_com', 210000000.0),
#   ('pseudocrawl-filtered_244_www_df_cl', 200000000.0),
#   ('pseudocrawl-filtered_62_www_lapagina_com_sv', 200000000.0),
#   ('pseudocrawl-filtered_280_salamancartvaldia_es', 200000000.0),
#   ('wikibooks_filtered', 102475942),
#   ('ted_talks_iwslt', 67403011),
#   ('wikivoyage_filtered', 43656153),
#   ('wikinews_filtered', 34612645),
#   ('qedcorpus', 27963841),
#   ('scielo', 22832426),
#   ('wikiquote_filtered', 21791340),
#   ('wikiversity_filtered', 21033636),
#   ('bloom', 1938115)],
#  'eu': [('bsbasque', 1105192579),
#   ('wikipedia', 489873420),
#   ('pseudocrawl-filtered_635_www_berria_eus', 230000000.0),
#   ('pseudocrawl-filtered_637_www_argia_eus', 150000000.0),
#   ('pseudocrawl-filtered_506_goiena_eus', 110000000.0),
#   ('pseudocrawl-filtered_563_ahotsak_eus', 80000000.0),
#   ('opus100', 57043549),
#   ('wikisource_filtered', 32661422),
#   ('open_subtitles', 30477347),
#   ('wiktionary_filtered', 23642491),
#   ('wikibooks_filtered', 12455461),
#   ('ted_talks_iwslt', 1555594),
#   ('wikiquote_filtered', 781607)],
#  'fr': [('hal_archives_ouvertes', 87000000000),
#   ('wikisource_filtered', 12863943339),
#   ('uncorpus', 5333005747),
#   ('pseudocrawl-filtered_550_www_lemonde_fr', 5000000000),
#   ('open_subtitles', 3608572488),
#   ('wikipedia', 3362557896),
#   ('multi_un_2', 2665006701),
#   ('wiktionary_filtered', 2524311296),
#   ('project_gutenberg', 1317466511),
#   ('bnl_historical_newspapers', 858329082),
#   ('pseudocrawl-filtered_530_www_mediapart_fr', 800000000),
#   ('pseudocrawl-filtered_599_fr_globalvoices_org', 500000000),
#   ('the_pile_europarl', 377048839),
#   ('wikibooks_filtered', 145125988),
#   ('wikiversity_filtered', 128961195),
#   ('ted_talks_iwslt', 81797420),
#   ('wikinews_filtered', 66531900),
#   ('wikivoyage_filtered', 52912126),
#   ('wikiquote_filtered', 34816472),
#   ('ester', 21164003),
#   ('qedcorpus', 8282210),
#   ('bloom', 2000577),
#   ('book_dash_books', 20294)],
#  'id': [('indo4b', 48259523287),
#   ('indonesian_news_articles_2017', 832010916),
#   ('open_subtitles', 726419677),
#   ('pseudocrawl-filtered_572_tirto_id', 620000000.0),
#   ('pseudocrawl-filtered_549_www_cnnindonesia_com', 540000000.0),
#   ('wikipedia', 324044339),
#   ('pseudocrawl-filtered_545_www_detik_com', 310000000.0),
#   ('wiktionary_filtered', 262427317),
#   ('indonesian_news_corpus', 236313636),
#   ('pseudocrawl-filtered_512_kumparan_com', 210000000.0),
#   ('indosum', 205954315),
#   ('wikisource_filtered', 88146406),
#   ('opus100', 41900995),
#   ('ted_talks_iwslt', 31375484),
#   ('wikibooks_filtered', 24703317),
#   ('wikimedia_filtered', 15634167),
#   ('recibrew', 6481967),
#   ('indonli', 3921895),
#   ('wikiquote_filtered', 2489362),
#   ('bloom', 474211),
#   ('indonesian_frog_storytelling_corpus', 146572)],
#  'indic-as': [('wikisource_filtered', 221645918),
#   ('wikipedia', 70625772),
#   ('opus100', 11577124),
#   ('samanantar', 11189395),
#   ('ted_talks_iwslt', 20396),
#   ('wiktionary_filtered', 4180)],
#  'indic-bn': [('bangla_lm', 14311316764),
#   ('wikisource_filtered', 2928007533),
#   ('indic_nlp_corpus', 1562808480),
#   ('samanantar', 862843797),
#   ('wikipedia', 770588385),
#   ('opus100', 180470150),
#   ('open_subtitles', 42848908),
#   ('pib', 38043179),
#   ('bengali_question_answering', 23700749),
#   ('wiktionary_filtered', 13032509),
#   ('wikivoyage_filtered', 7338989),
#   ('ted_talks_iwslt', 5569915),
#   ('bangla_sentiment_classification_datasets', 3426008),
#   ('wikibooks_filtered', 2791342),
#   ('mkb', 1392895),
#   ('bloom', 968338)],
#  'indic-gu': [('indic_nlp_corpus', 1809915926),
#   ('samanantar', 379692195),
#   ('wikisource_filtered', 219522315),
#   ('wikipedia', 116956704),
#   ('opus100', 24133011),
#   ('pib', 24042997),
#   ('wikiquote_filtered', 2182721),
#   ('ted_talks_iwslt', 1628937),
#   ('mkb', 1601995),
#   ('wiktionary_filtered', 1575101),
#   ('bloom', 16088)],
#  'indic-hi': [('indic_nlp_corpus', 14167836773),
#   ('iitb_english_hindi_corpus', 9710786380),
#   ('samanantar', 1971207531),
#   ('pseudocrawl-filtered_667_www_bhaskar_com', 1450000000.0),
#   ('wikisource_filtered', 707730338),
#   ('wikipedia', 615409211),
#   ('pseudocrawl-filtered_515_www_aajtak_in', 490000000.0),
#   ('pib', 113729046),
#   ('wiktionary_filtered', 93109622),
#   ('opus100', 90144702),
#   ('wikibooks_filtered', 42662968),
#   ('ted_talks_iwslt', 13933590),
#   ('open_subtitles', 9486424),
#   ('wikiquote_filtered', 5323092),
#   ('qedcorpus', 4772646),
#   ('wikivoyage_filtered', 2100294),
#   ('wikiversity_filtered', 1333291),
#   ('mkb', 1281470),
#   ('bloom', 97175),
#   ('wikimedia_filtered', 96873)],
#  'indic-kn': [('indic_nlp_corpus', 3293790175),
#   ('samanantar', 595321690),
#   ('wikisource_filtered', 449264331),
#   ('wikipedia', 362405065),
#   ('wiktionary_filtered', 61997626),
#   ('opus100', 1466438),
#   ('wikiquote_filtered', 1448424),
#   ('ted_talks_iwslt', 1202170),
#   ('bloom', 973)],
#  'indic-ml': [('indic_nlp_corpus', 3992234898),
#   ('samanantar', 886777605),
#   ('wikipedia', 440123076),
#   ('wikisource_filtered', 397860584),
#   ('opus100', 153231131),
#   ('open_subtitles', 44840470),
#   ('wiktionary_filtered', 40982891),
#   ('pib', 20499054),
#   ('wikiquote_filtered', 3224572),
#   ('ted_talks_iwslt', 2200885),
#   ('wikibooks_filtered', 1967533),
#   ('mkb', 1500658),
#   ('bloom', 52796)],
#  'indic-mr': [('indic_nlp_corpus', 2398696742),
#   ('samanantar', 502539104),
#   ('wikisource_filtered', 339970574),
#   ('wikipedia', 228312272),
#   ('pib', 46282146),
#   ('ted_talks_iwslt', 5777432),
#   ('wikibooks_filtered', 2930647),
#   ('opus100', 2251271),
#   ('wiktionary_filtered', 2170092),
#   ('mkb', 1507525),
#   ('wikiquote_filtered', 659740),
#   ('bloom', 28707)],
#  'indic-ne': [('unsupervised_cross_lingual_representation_learning_at_scale',
#    4089717751)],
#  'indic-or': [('indic_nlp_corpus', 863081140),
#   ('samanantar', 142045048),
#   ('wiktionary_filtered', 72442406),
#   ('wikipedia', 67026650),
#   ('wikisource_filtered', 61063026),
#   ('pib', 36244896),
#   ('odiencorp', 27472572),
#   ('opus100', 1296912),
#   ('mkb', 189770),
#   ('bloom', 3185)],
#  'indic-pa': [('indic_nlp_corpus', 2163510409),
#   ('samanantar', 482350183),
#   ('wikipedia', 153364890),
#   ('wikisource_filtered', 133848234),
#   ('pib', 39834120),
#   ('wiktionary_filtered', 16945542),
#   ('opus100', 5929407),
#   ('wikibooks_filtered', 195936),
#   ('bloom', 12128),
#   ('ted_talks_iwslt', 2643)],
#  'indic-ta': [('indic_nlp_corpus', 7649569872),
#   ('wikisource_filtered', 1803374524),
#   ('samanantar', 807047122),
#   ('wikipedia', 739279705),
#   ('wiktionary_filtered', 259656599),
#   ('opus100', 58148403),
#   ('pib', 56254426),
#   ('wikinews_filtered', 19559751),
#   ('ted_talks_iwslt', 7250261),
#   ('wikiquote_filtered', 6710133),
#   ('wikibooks_filtered', 5334061),
#   ('open_subtitles', 3107498),
#   ('mkb', 1963679),
#   ('bloom', 51721)],
#  'indic-te': [('indic_nlp_corpus', 3633236244),
#   ('samanantar', 717946490),
#   ('wikipedia', 657179925),
#   ('wikisource_filtered', 605434589),
#   ('wiktionary_filtered', 93663644),
#   ('pib', 20719695),
#   ('wikibooks_filtered', 6661369),
#   ('opus100', 5066154),
#   ('open_subtitles', 2074388),
#   ('wikiquote_filtered', 1826318),
#   ('ted_talks_iwslt', 1555952),
#   ('mkb', 1263880),
#   ('bloom', 364)],
#  'indic-ur': [('leipzig_wortschatz_urdu-pk_web_2019_sentences', 1786077653),
#   ('urdu-monolingual-corpus', 798271364),
#   ('leipzig_wortschatz_urdu_newscrawl_2016_sentences', 646473354),
#   ('wikipedia', 322485666),
#   ('opus100', 169163468),
#   ('pib', 64040641),
#   ('wiktionary_filtered', 7326237),
#   ('wikibooks_filtered', 4987734),
#   ('ted_talks_iwslt', 3707396),
#   ('open_subtitles', 2226591),
#   ('wikiquote_filtered', 900604),
#   ('mkb', 175746),
#   ('bloom', 11080)],
#  'pt': [('brwac', 17890965850),
#   ('open_subtitles', 3834765590),
#   ('wikipedia', 1085161130),
#   ('scielo', 490399371),
#   ('the_pile_europarl', 359929387),
#   ('wikisource_filtered', 276430207),
#   ('pseudocrawl-filtered_672_pt_globalvoices_org', 220000000.0),
#   ('wiktionary_filtered', 178957580),
#   ('ted_talks_iwslt', 111984427),
#   ('project_gutenberg', 109306838),
#   ('wikinews_filtered', 90369686),
#   ('opus100', 60766355),
#   ('wikibooks_filtered', 58859038),
#   ('wikiversity_filtered', 32719585),
#   ('wikiquote_filtered', 22685411),
#   ('qedcorpus', 15558008),
#   ('wikivoyage_filtered', 12120467),
#   ('wikimedia_filtered', 1663815),
#   ('bloom', 544621)],
#  'vi': [('binhvq_news_corpus', 29924668961),
#   ('vinbigdata_monolingual_vlsp_2020', 3723552415),
#   ('vietai_sat', 731911219),
#   ('wikipedia', 493825495),
#   ('vinbigdata_mt_vlsp_2020', 349777700),
#   ('vntq_corpus_big', 255948742),
#   ('open_subtitles', 207368356),
#   ('wikisource_filtered', 159989119),
#   ('wiktionary_filtered', 129191579),
#   ('vietnamese_poetry', 106849374),
#   ('data_on_covid_19_news_coverage_in_vietnam', 81188778),
#   ('wikibooks_filtered', 71905347),
#   ('ted_talks_iwslt', 58677946),
#   ('opus100', 46780062),
#   ('wikivoyage_filtered', 11128881),
#   ('vinbigdata_asr_vlsp_2020', 11019228),
#   ('wikiquote_filtered', 4451067),
#   ('vietnamese_students_feedback', 1673707),
#   ('uit_vsmec', 541270),
#   ('bloom', 12115)],
#  'zhs': [('wudaocorpora', 203958584977),
#   ('du_reader', 3405319606),
#   ('uncorpus', 2295661459),
#   ('multi_un_2', 1373303462),
#   ('wikipedia', 940381872),
#   ('open_subtitles', 893297866),
#   ('wiktionary_filtered', 538210079),
#   ('pseudocrawl-filtered_503_www_zaobao_com_sg', 280000000.0),
#   ('project_gutenberg', 166964785),
#   ('opus100', 91861208),
#   ('pseudocrawl-filtered_674_ai_baidu_com', 60000000.0),
#   ('ted_talks_iwslt', 59882658),
#   ('wikinews_filtered', 48800580),
#   ('wikibooks_filtered', 35301468),
#   ('wikiversity_filtered', 34936693),
#   ('wikivoyage_filtered', 21455344),
#   ('wikiquote_filtered', 14377874),
#   ('qedcorpus', 5434751),
#   ('bloom', 1470)],
#  'zht': [('wikipedia', 941050948), ('qedcorpus', 4627768)],
#  'code': [('github-no-gpl', 158614921210), ('stackexchange', 29479217221)],
#  'nigercongo-sw': [('aggregated', 264036370)],
#  'nigercongo-yo': [('aggregated', 70039249)],
#  'nigercongo-rw': [('aggregated', 42145941)],
#  'nigercongo-xh': [('aggregated', 14467934)],
#  'nigercongo-ig': [('aggregated', 12520386)],
#  'nigercongo-zu': [('aggregated', 8959591)],
#  'nigercongo-sn': [('aggregated', 7489361)],
#  'nigercongo-lg': [('aggregated', 4538572)],
#  'nigercongo-wo': [('aggregated', 3526807)],
#  'nigercongo-rn': [('aggregated', 3216020)],
#  'nigercongo-fon': [('aggregated', 1973909)],
#  'nigercongo-nso': [('aggregated', 1932754)],
#  'nigercongo-ln': [('aggregated', 1631248)],
#  'nigercongo-tn': [('aggregated', 1533108)],
#  'nigercongo-tw': [('aggregated', 1241938)],
#  'nigercongo-ny': [('aggregated', 1194349)],
#  'nigercongo-st': [('aggregated', 754055)],
#  'nigercongo-ts': [('aggregated', 725380)],
#  'nigercongo-ak': [('aggregated', 670157)],
#  'nigercongo-bm': [('aggregated', 385450)],
#  'nigercongo-ki': [('aggregated', 362345)],
#  'nigercongo-tum': [('aggregated', 179586)]}

# %%
lang_aggreg = sorted(
    [(ln, sum([ct for n, ct in ls])) for ln, ls in lang_to_sizes.items()],
    key=lambda x:x[1],
    reverse=True,
)

for ln, ct in lang_aggreg:
    print(f"{ln:9s} - {ct / 1e9:.3f} GB")
# Out:
# en        - 797.914 GB
# zhs       - 214.224 GB
# code      - 188.094 GB
# fr        - 126.752 GB
# es        - 99.346 GB
# ar        - 69.654 GB
# id        - 52.742 GB
# vi        - 36.370 GB
# indic-hi  - 29.491 GB
# pt        - 24.853 GB
# indic-bn  - 20.755 GB
# ca        - 16.585 GB
# indic-ta  - 11.417 GB
# indic-ml  - 5.985 GB
# indic-te  - 5.747 GB
# indic-kn  - 4.767 GB
# indic-ne  - 4.090 GB
# indic-ur  - 3.806 GB
# indic-mr  - 3.531 GB
# indic-pa  - 2.996 GB
# indic-gu  - 2.581 GB
# eu        - 2.324 GB
# indic-or  - 1.271 GB
# zht       - 0.946 GB
# indic-as  - 0.315 GB
# nigercongo-sw - 0.264 GB
# nigercongo-yo - 0.070 GB
# nigercongo-rw - 0.042 GB
# nigercongo-xh - 0.014 GB
# nigercongo-ig - 0.013 GB
# nigercongo-zu - 0.009 GB
# nigercongo-sn - 0.007 GB
# nigercongo-lg - 0.005 GB
# nigercongo-wo - 0.004 GB
# nigercongo-rn - 0.003 GB
# nigercongo-fon - 0.002 GB
# nigercongo-nso - 0.002 GB
# nigercongo-ln - 0.002 GB
# nigercongo-tn - 0.002 GB
# nigercongo-tw - 0.001 GB
# nigercongo-ny - 0.001 GB
# nigercongo-st - 0.001 GB
# nigercongo-ts - 0.001 GB
# nigercongo-ak - 0.001 GB
# nigercongo-bm - 0.000 GB
# nigercongo-ki - 0.000 GB
# nigercongo-tum - 0.000 GB

# %%
# Thomas: My implementation of alpha sampling
from typing import List, Tuple
alpha = 0.3

# Compute alpha sampling on languages https://arxiv.org/pdf/1901.07291.pdf
def alpha_probabilities(language_sizes: List[Tuple[str, int]], alpha: float) -> List[Tuple[str, float]]:
    # canonical probabilities
    canonical_normalisation_factor = sum([elt[1] for elt in language_sizes])
    canonical_probabilities = [(elt[0], elt[1]/canonical_normalisation_factor) for elt in language_sizes]
    
    # alpha 
    alpha_normalisation_factor = sum([elt[1] ** alpha for elt in canonical_probabilities])
    alpha_probabilities = [(elt[0], elt[1] ** alpha /alpha_normalisation_factor) for elt in canonical_probabilities]
    return alpha_probabilities, canonical_probabilities

alpha_probabilities, canonical_probabilities = alpha_probabilities(lang_aggreg, alpha)
for (lang, alpha), (_, canon) in zip(alpha_probabilities, canonical_probabilities):
    print(f"{lang:15s} - {alpha:.2e}")
# Out:
# en              - 1.09e-01 4.62e-01
# zhs             - 7.32e-02 1.24e-01
# code            - 7.04e-02 1.09e-01
# fr              - 6.25e-02 7.34e-02
# es              - 5.81e-02 5.75e-02
# ar              - 5.23e-02 4.03e-02
# id              - 4.81e-02 3.05e-02
# vi              - 4.30e-02 2.11e-02
# indic-hi        - 4.04e-02 1.71e-02
# pt              - 3.84e-02 1.44e-02
# indic-bn        - 3.63e-02 1.20e-02
# ca              - 3.40e-02 9.60e-03
# indic-ta        - 3.04e-02 6.61e-03
# indic-ml        - 2.50e-02 3.47e-03
# indic-te        - 2.47e-02 3.33e-03
# indic-kn        - 2.34e-02 2.76e-03
# indic-ne        - 2.23e-02 2.37e-03
# indic-ur        - 2.18e-02 2.20e-03
# indic-mr        - 2.14e-02 2.04e-03
# indic-pa        - 2.03e-02 1.73e-03
# indic-gu        - 1.94e-02 1.49e-03
# eu              - 1.88e-02 1.35e-03
# indic-or        - 1.57e-02 7.36e-04
# zht             - 1.44e-02 5.48e-04
# indic-as        - 1.03e-02 1.82e-04
# nigercongo-sw   - 9.81e-03 1.53e-04
# nigercongo-yo   - 6.59e-03 4.06e-05
# nigercongo-rw   - 5.66e-03 2.44e-05
# nigercongo-xh   - 4.11e-03 8.38e-06
# nigercongo-ig   - 3.93e-03 7.25e-06
# nigercongo-zu   - 3.56e-03 5.19e-06
# nigercongo-sn   - 3.37e-03 4.34e-06
# nigercongo-lg   - 2.90e-03 2.63e-06
# nigercongo-wo   - 2.69e-03 2.04e-06
# nigercongo-rn   - 2.61e-03 1.86e-06
# nigercongo-fon  - 2.26e-03 1.14e-06
# nigercongo-nso  - 2.24e-03 1.12e-06
# nigercongo-ln   - 2.13e-03 9.45e-07
# nigercongo-tn   - 2.09e-03 8.88e-07
# nigercongo-tw   - 1.97e-03 7.19e-07
# nigercongo-ny   - 1.94e-03 6.92e-07
# nigercongo-st   - 1.69e-03 4.37e-07
# nigercongo-ts   - 1.67e-03 4.20e-07
# nigercongo-ak   - 1.63e-03 3.88e-07
# nigercongo-bm   - 1.38e-03 2.23e-07
# nigercongo-ki   - 1.36e-03 2.10e-07
# nigercongo-tum  - 1.10e-03 1.04e-07

# %%
# Find which dataset constrains the sampling
def get_constained_language(language_sizes: List[Tuple[str, int]], alpha_probabilities: List[Tuple[str,float]]) -> int:
    selected_index = 0
    found_constrained_language_index = False
    while not found_constrained_language_index:
        selected_size = language_sizes[selected_index][1]
        selected_alpha = alpha_probabilities[selected_index][1]
        found_constrained_language_index = True
        for index, ((lang1, alpha), (lang2, size)) in enumerate(zip(alpha_probabilities, language_sizes)):
            assert lang1 == lang2
            expected_size = int(selected_size * alpha / selected_alpha)
            if expected_size > size:
                selected_index = index
                found_constrained_language_index = False
                break
    return selected_index

constrained_language_index = get_constained_language(lang_aggreg, alpha_probabilities)
print(lang_aggreg[constrained_language_index])

# Sanity check all the sizes are smaller than the expected one
constrained_size = lang_aggreg[constrained_language_index][1]
constrained_alpha = alpha_probabilities[constrained_language_index][1]
constrained_ratio = constrained_size / constrained_alpha
for (lang1, alpha), (lang2, size) in zip(alpha_probabilities, lang_aggreg):
    assert lang1 == lang2
    expected_size = alpha * constrained_ratio
    assert expected_size <= size
# Out:
# ('nigercongo-tum', 179586)

# %%
# Get accumulated dataset give current alpha ratio
alpha_dataset = [(lang, alpha * constrained_ratio) for (lang, alpha)in alpha_probabilities]
current_size = sum([size for (_, size) in alpha_dataset])

for (lang1, size), (lang2, original_size) in zip(alpha_dataset, lang_aggreg):
    print(f"{lang:15s} - {size / 1e9:.3f} GB - percentage conserved: {size / original_size} - Original size: {original_size / 1e9:.3f} GB")

print(current_size)
# Out:
# nigercongo-tum  - 0.018 GB - percentage conserved: 2.2213723649024766e-05 - Original size: 797.914 GB
# nigercongo-tum  - 0.012 GB - percentage conserved: 5.5767781074433704e-05 - Original size: 214.224 GB
# nigercongo-tum  - 0.011 GB - percentage conserved: 6.108408190702272e-05 - Original size: 188.094 GB
# nigercongo-tum  - 0.010 GB - percentage conserved: 8.052351225631972e-05 - Original size: 126.752 GB
# nigercongo-tum  - 0.009 GB - percentage conserved: 9.54963864775861e-05 - Original size: 99.346 GB
# nigercongo-tum  - 0.009 GB - percentage conserved: 0.00012244139178653886 - Original size: 69.654 GB
# nigercongo-tum  - 0.008 GB - percentage conserved: 0.0001487583331056574 - Original size: 52.742 GB
# nigercongo-tum  - 0.007 GB - percentage conserved: 0.00019295967857551043 - Original size: 36.370 GB
# nigercongo-tum  - 0.007 GB - percentage conserved: 0.00022346404596399236 - Original size: 29.491 GB
# nigercongo-tum  - 0.006 GB - percentage conserved: 0.00025189715841525596 - Original size: 24.853 GB
# nigercongo-tum  - 0.006 GB - percentage conserved: 0.0002857607985192263 - Original size: 20.755 GB
# nigercongo-tum  - 0.006 GB - percentage conserved: 0.00033433946211935224 - Original size: 16.585 GB
# nigercongo-tum  - 0.005 GB - percentage conserved: 0.0004342063183046786 - Original size: 11.417 GB
# nigercongo-tum  - 0.004 GB - percentage conserved: 0.000682371099606288 - Original size: 5.985 GB
# nigercongo-tum  - 0.004 GB - percentage conserved: 0.0007021041197723583 - Original size: 5.747 GB
# nigercongo-tum  - 0.004 GB - percentage conserved: 0.0008002500378533659 - Original size: 4.767 GB
# nigercongo-tum  - 0.004 GB - percentage conserved: 0.0008908516702045474 - Original size: 4.090 GB
# nigercongo-tum  - 0.004 GB - percentage conserved: 0.0009368601447725242 - Original size: 3.806 GB
# nigercongo-tum  - 0.003 GB - percentage conserved: 0.000987305285938522 - Original size: 3.531 GB
# nigercongo-tum  - 0.003 GB - percentage conserved: 0.0011076744243325805 - Original size: 2.996 GB
# nigercongo-tum  - 0.003 GB - percentage conserved: 0.0012294406460614333 - Original size: 2.581 GB
# nigercongo-tum  - 0.003 GB - percentage conserved: 0.001323326032811168 - Original size: 2.324 GB
# nigercongo-tum  - 0.003 GB - percentage conserved: 0.002018928765741319 - Original size: 1.271 GB
# nigercongo-tum  - 0.002 GB - percentage conserved: 0.0024829627479949485 - Original size: 0.946 GB
# nigercongo-tum  - 0.002 GB - percentage conserved: 0.005359357880416297 - Original size: 0.315 GB
# nigercongo-tum  - 0.002 GB - percentage conserved: 0.006064934385615935 - Original size: 0.264 GB
# nigercongo-tum  - 0.001 GB - percentage conserved: 0.015355066358926146 - Original size: 0.070 GB
# nigercongo-tum  - 0.001 GB - percentage conserved: 0.021910975120806853 - Original size: 0.042 GB
# nigercongo-tum  - 0.001 GB - percentage conserved: 0.046313347309576605 - Original size: 0.014 GB
# nigercongo-tum  - 0.001 GB - percentage conserved: 0.05124580637629791 - Original size: 0.013 GB
# nigercongo-tum  - 0.001 GB - percentage conserved: 0.06477225317650907 - Original size: 0.009 GB
# nigercongo-tum  - 0.001 GB - percentage conserved: 0.07343099259040192 - Original size: 0.007 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.10426709493027758 - Original size: 0.005 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.12440090742010616 - Original size: 0.004 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.1326989894261693 - Original size: 0.003 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.18675048788509738 - Original size: 0.002 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.1895252715643431 - Original size: 0.002 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.21341588392795863 - Original size: 0.002 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.22288960225350446 - Original size: 0.002 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.2582978511920527 - Original size: 0.001 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.26545985872973177 - Original size: 0.001 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.36627613037134427 - Original size: 0.001 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.3763525215344372 - Original size: 0.001 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.3978021658425977 - Original size: 0.001 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.5858859711890976 - Original size: 0.000 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 0.6117939009300408 - Original size: 0.000 GB
# nigercongo-tum  - 0.000 GB - percentage conserved: 1.0 - Original size: 0.000 GB
# 163216094.12548348

# %%
# Clip the dataset so that high ressource have the same amount of data
target_size = int(800e9)
target_size = int(160000000)
assert target_size < current_size, f"Current size: {current_size}, and target: {target_size}, {current_size / target_size}"

import numpy as np

# Find breaking point, ie index at which cumulative sum exceeds current_size
increasing_alpha_lang = alpha_dataset[::-1]
tmp_size = 0
previous_size = 0
for i,(_, size) in enumerate(increasing_alpha_lang):
    # We simulate if we add `size` for each language that still have data left.
    tmp_size += i * (size - previous_size)
    previous_size = size
    if tmp_size > target_size:
        breaking_index = i
        clipped_size = size - (tmp_size - target_size) / i

print(clipped_size)
clipped_alpha_dataset = [(lang, min(size, clipped_size)) for (lang, size) in alpha_dataset]
norm = sum([size for (_, size) in clipped_alpha_dataset])
for (lang, size)in clipped_alpha_dataset:
    print(f"{lang:15s} - {size / norm * 800:.1f} GB")

print(f"Target size: {target_size}. Computed size: {sum([size for (_, size) in clipped_alpha_dataset])}")
# Out:
# 6641118.405033341
# en              - 40.2 GB
# zhs             - 40.2 GB
# code            - 40.2 GB
# fr              - 40.2 GB
# es              - 40.2 GB
# ar              - 40.2 GB
# id              - 40.2 GB
# vi              - 40.2 GB
# indic-hi        - 39.9 GB
# pt              - 37.9 GB
# indic-bn        - 35.9 GB
# ca              - 33.6 GB
# indic-ta        - 30.0 GB
# indic-ml        - 24.7 GB
# indic-te        - 24.4 GB
# indic-kn        - 23.1 GB
# indic-ne        - 22.1 GB
# indic-ur        - 21.6 GB
# indic-mr        - 21.1 GB
# indic-pa        - 20.1 GB
# indic-gu        - 19.2 GB
# eu              - 18.6 GB
# indic-or        - 15.5 GB
# zht             - 14.2 GB
# indic-as        - 10.2 GB
# nigercongo-sw   - 9.7 GB
# nigercongo-yo   - 6.5 GB
# nigercongo-rw   - 5.6 GB
# nigercongo-xh   - 4.1 GB
# nigercongo-ig   - 3.9 GB
# nigercongo-zu   - 3.5 GB
# nigercongo-sn   - 3.3 GB
# nigercongo-lg   - 2.9 GB
# nigercongo-wo   - 2.7 GB
# nigercongo-rn   - 2.6 GB
# nigercongo-fon  - 2.2 GB
# nigercongo-nso  - 2.2 GB
# nigercongo-ln   - 2.1 GB
# nigercongo-tn   - 2.1 GB
# nigercongo-tw   - 1.9 GB
# nigercongo-ny   - 1.9 GB
# nigercongo-st   - 1.7 GB
# nigercongo-ts   - 1.7 GB
# nigercongo-ak   - 1.6 GB
# nigercongo-bm   - 1.4 GB
# nigercongo-ki   - 1.3 GB
# nigercongo-tum  - 1.1 GB
# Target size: 160000000. Computed size: 132098029.97547959

# %%
target_size = int(800e9)
# target_size = int(600e9)

num_dsets = len(lang_aggreg)

ratios = {}
with_samples = []

# lang_aggreg: List[Tuple[str, int]]
prev_size = 0
current_size = 0
for i, (name, size) in enumerate(sorted(lang_aggreg, key=lambda x:x[1])):
    if current_size < target_size:
        add_size = min(size - prev_size, (target_size - current_size) // (num_dsets - i) + 1)
        current_size += add_size * (num_dsets - i)
        prev_size += add_size
    with_samples += [(name, size, prev_size)]
    
lang_to_target = {}
for ln, _, keep_size in sorted(with_samples, key=lambda x:x[1], reverse=True):
    lang_to_target[ln] = keep_size
    print(f"{ln:10s} - {keep_size / 1e9:.3f} GB")
    
print(f"{sum([elt[1] for elt in with_samples])/1e9:.3f}")

# Quentin version of whatever the previous loop does
prev_size = 0
current_size = 0
with_samples = []
for i, (name, size) in enumerate(sorted(lang_aggreg, key=lambda x:x[1])):
    if prev_size < target_size:
        add_size = min(size, (target_size - current_size) // (num_dsets - i) + 1)
        current_size += add_size * (num_dsets - i)
        prev_size += add_size
    with_samples += [(name, size, prev_size)]

lang_to_target = {}
for ln, _, keep_size in sorted(with_samples, key=lambda x:x[1], reverse=True):
    lang_to_target[ln] = keep_size
    print(f"{ln:10s} - {keep_size / 1e9:.3f} GB")

print(f"{sum([elt[1] for elt in with_samples])/1e9:.3f}")
# Out:
# en         - 99.996 GB
# zhs        - 99.996 GB
# code       - 99.996 GB
# fr         - 99.996 GB
# es         - 99.346 GB
# ar         - 69.654 GB
# id         - 52.742 GB
# vi         - 36.370 GB
# indic-hi   - 29.491 GB
# pt         - 24.853 GB
# indic-bn   - 20.755 GB
# ca         - 16.585 GB
# indic-ta   - 11.417 GB
# indic-ml   - 5.985 GB
# indic-te   - 5.747 GB
# indic-kn   - 4.767 GB
# indic-ne   - 4.090 GB
# indic-ur   - 3.806 GB
# indic-mr   - 3.531 GB
# indic-pa   - 2.996 GB
# indic-gu   - 2.581 GB
# eu         - 2.324 GB
# indic-or   - 1.271 GB
# zht        - 0.946 GB
# indic-as   - 0.315 GB
# nigercongo-sw - 0.264 GB
# nigercongo-yo - 0.070 GB
# nigercongo-rw - 0.042 GB
# nigercongo-xh - 0.014 GB
# nigercongo-ig - 0.013 GB
# nigercongo-zu - 0.009 GB
# nigercongo-sn - 0.007 GB
# nigercongo-lg - 0.005 GB
# nigercongo-wo - 0.004 GB
# nigercongo-rn - 0.003 GB
# nigercongo-fon - 0.002 GB
# nigercongo-nso - 0.002 GB
# nigercongo-ln - 0.002 GB
# nigercongo-tn - 0.002 GB
# nigercongo-tw - 0.001 GB
# nigercongo-ny - 0.001 GB
# nigercongo-st - 0.001 GB
# nigercongo-ts - 0.001 GB
# nigercongo-ak - 0.001 GB
# nigercongo-bm - 0.000 GB
# nigercongo-ki - 0.000 GB
# nigercongo-tum - 0.000 GB
# 1727.000
# en         - 47.374 GB
# zhs        - 47.374 GB
# code       - 47.374 GB
# fr         - 47.374 GB
# es         - 47.374 GB
# ar         - 47.374 GB
# id         - 47.374 GB
# vi         - 47.374 GB
# indic-hi   - 47.374 GB
# pt         - 47.374 GB
# indic-bn   - 47.374 GB
# ca         - 47.374 GB
# indic-ta   - 47.374 GB
# indic-ml   - 38.802 GB
# indic-te   - 32.816 GB
# indic-kn   - 27.070 GB
# indic-ne   - 22.303 GB
# indic-ur   - 18.213 GB
# indic-mr   - 14.407 GB
# indic-pa   - 10.876 GB
# indic-gu   - 7.880 GB
# eu         - 5.299 GB
# indic-or   - 2.975 GB
# zht        - 1.704 GB
# indic-as   - 0.759 GB
# nigercongo-sw - 0.444 GB
# nigercongo-yo - 0.179 GB
# nigercongo-rw - 0.109 GB
# nigercongo-xh - 0.067 GB
# nigercongo-ig - 0.053 GB
# nigercongo-zu - 0.040 GB
# nigercongo-sn - 0.031 GB
# nigercongo-lg - 0.024 GB
# nigercongo-wo - 0.019 GB
# nigercongo-rn - 0.016 GB
# nigercongo-fon - 0.013 GB
# nigercongo-nso - 0.011 GB
# nigercongo-ln - 0.009 GB
# nigercongo-tn - 0.007 GB
# nigercongo-tw - 0.006 GB
# nigercongo-ny - 0.004 GB
# nigercongo-st - 0.003 GB
# nigercongo-ts - 0.002 GB
# nigercongo-ak - 0.002 GB
# nigercongo-bm - 0.001 GB
# nigercongo-ki - 0.001 GB
# nigercongo-tum - 0.000 GB
# 1727.000

# %%
tokenization_ratios = []

total_size = 0

for lang, sizes in lang_to_sizes.items():
    ln_target_size = lang_to_target[lang]
    current_size = 0
    prev_size = 0
    num_dsets = len(sizes)
    for i, (name, size) in enumerate(sorted(sizes, key=lambda x:x[1])):
        if current_size < ln_target_size:
            add_size = min(size - prev_size, (ln_target_size - current_size) // (num_dsets - i) + 1)
            current_size += add_size * (num_dsets - i)
            prev_size += add_size
        ln = orig_lang.get(name, lang) if lang == "zh" else lang
        tokenization_ratios += [
            {
                'dataset_path': f"bigscience-catalogue-lm-data/lm_{ln}_{name}",
                'is_catalogue': True,
                'ratio': prev_size / target_size
            }]
    total_size += current_size

for dct in sorted(tokenization_ratios, key=lambda dct: dct['ratio'], reverse=True):
    print(f"{dct['ratio']:.2e} - {dct['dataset_path'].split('/')[1]}")
# Out:
# 1.12e-01 - lm_zhs_wudaocorpora
# 8.81e-02 - lm_code_github-no-gpl
# 7.53e-02 - lm_fr_hal_archives_ouvertes
# 6.03e-02 - lm_id_indo4b
# 3.74e-02 - lm_vi_binhvq_news_corpus
# 3.68e-02 - lm_code_stackexchange
# 2.24e-02 - lm_pt_brwac
# 2.18e-02 - lm_ar_openiti
# 2.11e-02 - lm_ar_arabic_billion_words
# 1.79e-02 - lm_indic-bn_bangla_lm
# 1.78e-02 - lm_ar_openiti_proc
# 1.77e-02 - lm_indic-hi_indic_nlp_corpus
# 1.61e-02 - lm_fr_wikisource_filtered
# 1.36e-02 - lm_ca_catalan_textual_corpus
# 1.21e-02 - lm_indic-hi_iitb_english_hindi_corpus
# 1.10e-02 - lm_en_wikipedia
# 1.10e-02 - lm_en_open_subtitles
# 1.10e-02 - lm_en_project_gutenberg
# 1.10e-02 - lm_en_the_pile_uspto
# 1.10e-02 - lm_en_s2orc_ai2_abstracts
# 1.10e-02 - lm_en_pmc
# 1.10e-02 - lm_en_arxiv
# 1.10e-02 - lm_en_s2orc_ai2_pdf_parses
# 9.56e-03 - lm_indic-ta_indic_nlp_corpus
# 8.83e-03 - lm_es_open_subtitles
# 7.29e-03 - lm_en_no_code_stackexchange
# 6.67e-03 - lm_fr_uncorpus
# 6.47e-03 - lm_ar_uncorpus
# 6.25e-03 - lm_fr_pseudocrawl-filtered_550_www_lemonde_fr
# 5.81e-03 - lm_es_uncorpus
# 5.70e-03 - lm_en_uncorpus
# 5.11e-03 - lm_indic-ne_unsupervised_cross_lingual_representation_learning_at_scale
# 4.99e-03 - lm_indic-ml_indic_nlp_corpus
# 4.79e-03 - lm_pt_open_subtitles
# 4.77e-03 - lm_en_wiktionary_filtered
# 4.65e-03 - lm_vi_vinbigdata_monolingual_vlsp_2020
# 4.61e-03 - lm_ar_open_subtitles
# 4.54e-03 - lm_indic-te_indic_nlp_corpus
# 4.51e-03 - lm_fr_open_subtitles
# 4.30e-03 - lm_es_pseudocrawl-filtered_100_www_aporrea_org
# 4.26e-03 - lm_zhs_du_reader
# 4.20e-03 - lm_fr_wikipedia
# 4.12e-03 - lm_indic-kn_indic_nlp_corpus
# 3.74e-03 - lm_es_pseudocrawl-filtered_396_www_eldiario_es
# 3.66e-03 - lm_indic-bn_wikisource_filtered
# 3.66e-03 - lm_ar_wikipedia
# 3.50e-03 - lm_en_pseudocrawl-filtered_689_www_abc_net_au
# 3.43e-03 - lm_es_pseudocrawl-filtered_341_es_cointelegraph_com
# 3.40e-03 - lm_es_wikipedia
# 3.36e-03 - lm_ca_catalan_general_crawling
# 3.34e-03 - lm_ar_multi_un_2
# 3.33e-03 - lm_fr_multi_un_2
# 3.31e-03 - lm_es_pseudocrawl-filtered_20_www_clarin_com
# 3.21e-03 - lm_en_multi_un_2
# 3.16e-03 - lm_fr_wiktionary_filtered
# 3.00e-03 - lm_indic-mr_indic_nlp_corpus
# 2.87e-03 - lm_es_multi_un_2
# 2.87e-03 - lm_zhs_uncorpus
# 2.75e-03 - lm_ar_pseudocrawl-filtered_595_mawdoo3_com
# 2.74e-03 - lm_es_pseudocrawl-filtered_424_www_lavanguardia_com
# 2.70e-03 - lm_indic-pa_indic_nlp_corpus
# 2.69e-03 - lm_es_pseudocrawl-filtered_63_www_lanacion_com_ar
# 2.67e-03 - lm_en_pseudocrawl-filtered_510_timesofindia_indiatimes_com
# 2.46e-03 - lm_indic-hi_samanantar
# 2.46e-03 - lm_es_pseudocrawl-filtered_255_elcomercio_pe
# 2.29e-03 - lm_es_pseudocrawl-filtered_333_www_elmundo_es
# 2.28e-03 - lm_ca_wikipedia
# 2.26e-03 - lm_indic-gu_indic_nlp_corpus
# 2.25e-03 - lm_indic-ta_wikisource_filtered
# 2.23e-03 - lm_indic-ur_leipzig_wortschatz_urdu-pk_web_2019_sentences
# 2.20e-03 - lm_es_pseudocrawl-filtered_349_www_eltiempo_com
# 2.00e-03 - lm_es_pseudocrawl-filtered_211_www_elcomercio_com
# 1.95e-03 - lm_indic-bn_indic_nlp_corpus
# 1.94e-03 - lm_es_pseudocrawl-filtered_267_www_elperiodico_com_es
# 1.83e-03 - lm_es_pseudocrawl-filtered_181_noticiassin_com
# 1.81e-03 - lm_indic-hi_pseudocrawl-filtered_667_www_bhaskar_com
# 1.80e-03 - lm_es_pseudocrawl-filtered_354_www_lagaceta_com_ar
# 1.75e-03 - lm_es_pseudocrawl-filtered_263_www_lasexta_com
# 1.74e-03 - lm_en_pseudocrawl-filtered_497_www_straitstimes_com
# 1.74e-03 - lm_es_pseudocrawl-filtered_198_www_eleconomista_es
# 1.74e-03 - lm_es_pseudocrawl-filtered_409_www_proceso_com_mx
# 1.72e-03 - lm_es_pseudocrawl-filtered_215_www_lainformacion_com
# 1.72e-03 - lm_zhs_multi_un_2
# 1.65e-03 - lm_fr_project_gutenberg
# 1.64e-03 - lm_es_pseudocrawl-filtered_146_www_perfil_com
# 1.62e-03 - lm_es_pseudocrawl-filtered_429_cadenaser_com
# 1.57e-03 - lm_ar_wikisource_filtered
# 1.55e-03 - lm_es_pseudocrawl-filtered_189_www_eleconomista_com_mx
# 1.51e-03 - lm_es_pseudocrawl-filtered_103_www_elmostrador_cl
# 1.38e-03 - lm_eu_bsbasque
# 1.36e-03 - lm_pt_wikipedia
# 1.35e-03 - lm_ar_tashkeela
# 1.30e-03 - lm_es_pseudocrawl-filtered_136_valenciaplaza_com
# 1.30e-03 - lm_es_wikisource_filtered
# 1.28e-03 - lm_es_pseudocrawl-filtered_518_www_elcolombiano_com
# 1.28e-03 - lm_es_pseudocrawl-filtered_248_www_telesurtv_net
# 1.18e-03 - lm_zht_wikipedia
# 1.18e-03 - lm_zhs_wikipedia
# 1.18e-03 - lm_es_pseudocrawl-filtered_237_www_cronista_com
# 1.18e-03 - lm_es_pseudocrawl-filtered_245_www_noticiasdenavarra_com
# 1.12e-03 - lm_zhs_open_subtitles
# 1.11e-03 - lm_es_pseudocrawl-filtered_157_www_elsoldemexico_com_mx
# 1.11e-03 - lm_indic-ml_samanantar
# 1.08e-03 - lm_indic-or_indic_nlp_corpus
# 1.08e-03 - lm_indic-bn_samanantar
# 1.07e-03 - lm_fr_bnl_historical_newspapers
# 1.06e-03 - lm_es_pseudocrawl-filtered_58_www_levante_emv_com
# 1.04e-03 - lm_id_indonesian_news_articles_2017
# 1.03e-03 - lm_es_pseudocrawl-filtered_641_es_globalvoices_org
# 1.01e-03 - lm_es_pseudocrawl-filtered_299_www_lne_es
# 1.01e-03 - lm_indic-ta_samanantar
# 1.00e-03 - lm_fr_pseudocrawl-filtered_530_www_mediapart_fr
# 9.98e-04 - lm_indic-ur_urdu-monolingual-corpus
# 9.75e-04 - lm_es_pseudocrawl-filtered_79_www_laopiniondemurcia_es
# 9.63e-04 - lm_indic-bn_wikipedia
# 9.37e-04 - lm_es_pseudocrawl-filtered_249_www_telecinco_es
# 9.25e-04 - lm_en_pseudocrawl-filtered_638_globalvoices_org
# 9.24e-04 - lm_indic-ta_wikipedia
# 9.15e-04 - lm_vi_vietai_sat
# 9.13e-04 - lm_es_pseudocrawl-filtered_287_www_cibercuba_com
# 9.08e-04 - lm_id_open_subtitles
# 8.97e-04 - lm_indic-te_samanantar
# 8.88e-04 - lm_es_pseudocrawl-filtered_86_www_motorpasion_com
# 8.88e-04 - lm_es_pseudocrawl-filtered_373_www_farodevigo_es
# 8.85e-04 - lm_indic-hi_wikisource_filtered
# 8.72e-04 - lm_en_wikibooks_filtered
# 8.38e-04 - lm_es_pseudocrawl-filtered_209_misionesonline_net
# 8.25e-04 - lm_es_pseudocrawl-filtered_71_www_rtve_es
# 8.25e-04 - lm_es_pseudocrawl-filtered_381_www_cuartopoder_es
# 8.21e-04 - lm_indic-te_wikipedia
# 8.12e-04 - lm_es_pseudocrawl-filtered_288_www_marca_com
# 8.08e-04 - lm_indic-ur_leipzig_wortschatz_urdu_newscrawl_2016_sentences
# 8.00e-04 - lm_es_pseudocrawl-filtered_430_www_eldiario_ec
# 8.00e-04 - lm_es_pseudocrawl-filtered_324_gestion_pe
# 7.88e-04 - lm_es_pseudocrawl-filtered_67_www_elpais_cr
# 7.75e-04 - lm_es_pseudocrawl-filtered_203_www_que_es
# 7.75e-04 - lm_es_pseudocrawl-filtered_405_www_emol_com
# 7.75e-04 - lm_id_pseudocrawl-filtered_572_tirto_id
# 7.69e-04 - lm_indic-hi_wikipedia
# 7.63e-04 - lm_es_pseudocrawl-filtered_213_www_hola_com
# 7.57e-04 - lm_indic-te_wikisource_filtered
# 7.44e-04 - lm_indic-kn_samanantar
# 7.37e-04 - lm_es_pseudocrawl-filtered_675_www_elespectador_com
# 7.37e-04 - lm_es_pseudocrawl-filtered_257_www_diaridetarragona_com
# 7.27e-04 - lm_ar_sanad
# 6.87e-04 - lm_es_pseudocrawl-filtered_226_www_ole_com_ar
# 6.87e-04 - lm_es_pseudocrawl-filtered_317_diariocorreo_pe
# 6.87e-04 - lm_es_pseudocrawl-filtered_165_www_ticbeat_com
# 6.87e-04 - lm_es_pseudocrawl-filtered_401_www_elperiodicodemexico_com
# 6.75e-04 - lm_es_pseudocrawl-filtered_359_www_efeverde_com
# 6.75e-04 - lm_es_pseudocrawl-filtered_256_www_laprovincia_es
# 6.75e-04 - lm_id_pseudocrawl-filtered_549_www_cnnindonesia_com
# 6.73e-04 - lm_zhs_wiktionary_filtered
# 6.63e-04 - lm_es_pseudocrawl-filtered_78_www_listindiario_com
# 6.50e-04 - lm_es_pseudocrawl-filtered_28_www_fayerwayer_com
# 6.38e-04 - lm_en_pseudocrawl-filtered_498_www_channelnewsasia_com
# 6.28e-04 - lm_indic-mr_samanantar
# 6.25e-04 - lm_es_pseudocrawl-filtered_229_www_expansion_com
# 6.25e-04 - lm_es_pseudocrawl-filtered_253_www_debate_com_mx
# 6.25e-04 - lm_fr_pseudocrawl-filtered_599_fr_globalvoices_org
# 6.17e-04 - lm_vi_wikipedia
# 6.13e-04 - lm_pt_scielo
# 6.12e-04 - lm_es_pseudocrawl-filtered_130_www_elperiodicomediterraneo_com
# 6.12e-04 - lm_es_pseudocrawl-filtered_376_www_elpopular_com_ar
# 6.12e-04 - lm_indic-hi_pseudocrawl-filtered_515_www_aajtak_in
# 6.12e-04 - lm_eu_wikipedia
# 6.03e-04 - lm_indic-pa_samanantar
# 6.00e-04 - lm_es_pseudocrawl-filtered_232_tn_com_ar
# 6.00e-04 - lm_es_pseudocrawl-filtered_44_ladiaria_com_uy
# 6.00e-04 - lm_es_pseudocrawl-filtered_220_www_vanguardia_com_mx
# 5.90e-04 - lm_es_wiktionary_filtered
# 5.88e-04 - lm_es_pseudocrawl-filtered_90_peru_com
# 5.75e-04 - lm_ar_ksucca
# 5.75e-04 - lm_es_pseudocrawl-filtered_320_www_paginasiete_bo
# 5.62e-04 - lm_es_pseudocrawl-filtered_392_www_muypymes_com
# 5.62e-04 - lm_es_pseudocrawl-filtered_169_www_el_carabobeno_com
# 5.62e-04 - lm_indic-kn_wikisource_filtered
# 5.50e-04 - lm_indic-ml_wikipedia
# 5.38e-04 - lm_en_pseudocrawl-filtered_304_www_semana_com
# 5.38e-04 - lm_es_pseudocrawl-filtered_91_www_diario26_com
# 5.25e-04 - lm_es_pseudocrawl-filtered_315_lasillavacia_com
# 5.25e-04 - lm_es_pseudocrawl-filtered_431_www_elperiodicoextremadura_com
# 5.05e-04 - lm_en_wikiquote_filtered
# 5.05e-04 - lm_en_royal_society_corpus
# 4.97e-04 - lm_indic-ml_wikisource_filtered
# 4.96e-04 - lm_ar_brad_2
# 4.87e-04 - lm_es_pseudocrawl-filtered_53_www_expreso_ec
# 4.87e-04 - lm_es_pseudocrawl-filtered_404_www_telam_com_ar
# 4.75e-04 - lm_indic-gu_samanantar
# 4.71e-04 - lm_fr_the_pile_europarl
# 4.63e-04 - lm_es_pseudocrawl-filtered_116_www_latribuna_hn
# 4.53e-04 - lm_indic-kn_wikipedia
# 4.50e-04 - lm_es_pseudocrawl-filtered_277_www_entornointeligente_com
# 4.50e-04 - lm_es_pseudocrawl-filtered_172_www_rionegro_com_ar
# 4.50e-04 - lm_es_pseudocrawl-filtered_167_www_ambientum_com
# 4.50e-04 - lm_es_pseudocrawl-filtered_21_www_elperiodicodearagon_com
# 4.50e-04 - lm_pt_the_pile_europarl
# 4.45e-04 - lm_es_the_pile_europarl
# 4.38e-04 - lm_es_pseudocrawl-filtered_34_www_losandes_com_ar
# 4.37e-04 - lm_vi_vinbigdata_mt_vlsp_2020
# 4.25e-04 - lm_es_pseudocrawl-filtered_325_www_laprensa_hn
# 4.25e-04 - lm_es_pseudocrawl-filtered_250_www_cooperativa_cl
# 4.25e-04 - lm_es_pseudocrawl-filtered_246_www_eldiarionuevodia_com_ar
# 4.25e-04 - lm_indic-mr_wikisource_filtered
# 4.18e-04 - lm_en_the_pile_europarl
# 4.12e-04 - lm_es_pseudocrawl-filtered_223_www_eltambor_es
# 4.05e-04 - lm_id_wikipedia
# 4.03e-04 - lm_indic-ur_wikipedia
# 4.03e-04 - lm_ca_tecla
# 4.00e-04 - lm_en_pseudocrawl-filtered_501_theindependent_sg
# 4.00e-04 - lm_es_pseudocrawl-filtered_276_radio_uchile_cl
# 4.00e-04 - lm_es_pseudocrawl-filtered_231_ojo_pe
# 3.87e-04 - lm_es_pseudocrawl-filtered_422_www_formulatv_com
# 3.87e-04 - lm_es_pseudocrawl-filtered_417_www_radiolaprimerisima_com
# 3.87e-04 - lm_es_pseudocrawl-filtered_406_www_americaeconomia_com
# 3.87e-04 - lm_es_pseudocrawl-filtered_367_elcorreoweb_es
# 3.87e-04 - lm_id_pseudocrawl-filtered_545_www_detik_com
# 3.83e-04 - lm_en_wikiversity_filtered
# 3.75e-04 - lm_es_pseudocrawl-filtered_23_www_elconfidencialdigital_com
# 3.75e-04 - lm_es_pseudocrawl-filtered_286_www_nacion_com
# 3.62e-04 - lm_es_project_gutenberg
# 3.50e-04 - lm_es_pseudocrawl-filtered_294_www_laopinion_com_co
# 3.50e-04 - lm_zhs_pseudocrawl-filtered_503_www_zaobao_com_sg
# 3.46e-04 - lm_pt_wikisource_filtered
# 3.38e-04 - lm_es_pseudocrawl-filtered_118_www_elheraldo_hn
# 3.38e-04 - lm_es_pseudocrawl-filtered_386_www_prensalibre_com
# 3.38e-04 - lm_es_pseudocrawl-filtered_233_www_dinero_com
# 3.38e-04 - lm_es_pseudocrawl-filtered_254_diario_mx
# 3.34e-04 - lm_en_wikivoyage_filtered
# 3.30e-04 - lm_nigercongo-sw_aggregated
# 3.28e-04 - lm_id_wiktionary_filtered
# 3.25e-04 - lm_es_pseudocrawl-filtered_182_correodelsur_com
# 3.25e-04 - lm_indic-ta_wiktionary_filtered
# 3.23e-04 - lm_ca_catalan_government_crawling
# 3.20e-04 - lm_vi_vntq_corpus_big
# 3.13e-04 - lm_es_pseudocrawl-filtered_374_www_talcualdigital_com
# 3.00e-04 - lm_es_pseudocrawl-filtered_207_elimpulso_com
# 3.00e-04 - lm_es_pseudocrawl-filtered_125_www_noticiasde_es
# 3.00e-04 - lm_es_pseudocrawl-filtered_420_www_retema_es
# 2.98e-04 - lm_ar_osac
# 2.95e-04 - lm_id_indonesian_news_corpus
# 2.87e-04 - lm_en_pseudocrawl-filtered_534_www_nairaland_com
# 2.87e-04 - lm_en_pseudocrawl-filtered_159_www_postcrescent_com
# 2.87e-04 - lm_en_pseudocrawl-filtered_487_thesmartlocal_com
# 2.87e-04 - lm_es_pseudocrawl-filtered_219_www_aguasresiduales_info
# 2.87e-04 - lm_es_pseudocrawl-filtered_153_financialfood_es
# 2.87e-04 - lm_es_pseudocrawl-filtered_56_www_eluniverso_com
# 2.87e-04 - lm_eu_pseudocrawl-filtered_635_www_berria_eus
# 2.85e-04 - lm_indic-mr_wikipedia
# 2.77e-04 - lm_indic-as_wikisource_filtered
# 2.75e-04 - lm_es_pseudocrawl-filtered_158_www_diariodeleon_es
# 2.75e-04 - lm_pt_pseudocrawl-filtered_672_pt_globalvoices_org
# 2.74e-04 - lm_indic-gu_wikisource_filtered
# 2.70e-04 - lm_ca_wiktionary_filtered
# 2.62e-04 - lm_es_pseudocrawl-filtered_32_www_elexpresso_com
# 2.62e-04 - lm_es_pseudocrawl-filtered_30_www_radiocable_com
# 2.62e-04 - lm_id_pseudocrawl-filtered_512_kumparan_com
# 2.59e-04 - lm_vi_open_subtitles
# 2.57e-04 - lm_id_indosum
# 2.50e-04 - lm_es_pseudocrawl-filtered_244_www_df_cl
# 2.50e-04 - lm_es_pseudocrawl-filtered_62_www_lapagina_com_sv
# 2.50e-04 - lm_es_pseudocrawl-filtered_280_salamancartvaldia_es
# 2.26e-04 - lm_indic-bn_opus100
# 2.24e-04 - lm_pt_wiktionary_filtered
# 2.11e-04 - lm_indic-ur_opus100
# 2.09e-04 - lm_zhs_project_gutenberg
# 2.00e-04 - lm_vi_wikisource_filtered
# 1.92e-04 - lm_indic-pa_wikipedia
# 1.92e-04 - lm_indic-ml_opus100
# 1.88e-04 - lm_en_pseudocrawl-filtered_395_www_evwind_es
# 1.88e-04 - lm_eu_pseudocrawl-filtered_637_www_argia_eus
# 1.81e-04 - lm_fr_wikibooks_filtered
# 1.78e-04 - lm_indic-or_samanantar
# 1.75e-04 - lm_en_pseudocrawl-filtered_696_www_oercommons_org
# 1.75e-04 - lm_en_pseudocrawl-filtered_470_forums_hardwarezone_com_sg
# 1.73e-04 - lm_en_qedcorpus
# 1.67e-04 - lm_indic-pa_wikisource_filtered
# 1.62e-04 - lm_en_pseudocrawl-filtered_548_remezcla_com
# 1.61e-04 - lm_vi_wiktionary_filtered
# 1.61e-04 - lm_fr_wikiversity_filtered
# 1.50e-04 - lm_en_pseudocrawl-filtered_485_blog_moneysmart_sg
# 1.46e-04 - lm_indic-gu_wikipedia
# 1.42e-04 - lm_indic-hi_pib
# 1.40e-04 - lm_pt_ted_talks_iwslt
# 1.38e-04 - lm_en_pseudocrawl-filtered_499_www_today_com_news
# 1.38e-04 - lm_en_pseudocrawl-filtered_492_www_vivawoman_net
# 1.38e-04 - lm_eu_pseudocrawl-filtered_506_goiena_eus
# 1.37e-04 - lm_pt_project_gutenberg
# 1.34e-04 - lm_vi_vietnamese_poetry
# 1.28e-04 - lm_es_wikibooks_filtered
# 1.18e-04 - lm_ar_kalimat
# 1.17e-04 - lm_indic-te_wiktionary_filtered
# 1.17e-04 - lm_ar_ted_talks_iwslt
# 1.16e-04 - lm_indic-hi_wiktionary_filtered
# 1.16e-04 - lm_ca_wikisource_filtered
# 1.16e-04 - lm_ar_opus100
# 1.15e-04 - lm_zhs_opus100
# 1.13e-04 - lm_pt_wikinews_filtered
# 1.13e-04 - lm_indic-hi_opus100
# 1.12e-04 - lm_en_pseudocrawl-filtered_619_www_qut_edu_au
# 1.10e-04 - lm_id_wikisource_filtered
# 1.05e-04 - lm_en_wikinews_filtered
# 1.02e-04 - lm_fr_ted_talks_iwslt
# 1.02e-04 - lm_ca_ca_text_corpus
# 1.01e-04 - lm_vi_data_on_covid_19_news_coverage_in_vietnam
# 1.00e-04 - lm_en_pseudocrawl-filtered_483_alvinology_com
# 1.00e-04 - lm_en_pseudocrawl-filtered_502_www_ricemedia_co
# 1.00e-04 - lm_eu_pseudocrawl-filtered_563_ahotsak_eus
# 9.06e-05 - lm_indic-or_wiktionary_filtered
# 8.99e-05 - lm_vi_wikibooks_filtered
# 8.83e-05 - lm_indic-as_wikipedia
# 8.75e-05 - lm_nigercongo-yo_aggregated
# 8.43e-05 - lm_es_ted_talks_iwslt
# 8.38e-05 - lm_indic-or_wikipedia
# 8.32e-05 - lm_fr_wikinews_filtered
# 8.19e-05 - lm_en_ted_talks_iwslt
# 8.01e-05 - lm_indic-ur_pib
# 7.75e-05 - lm_indic-kn_wiktionary_filtered
# 7.63e-05 - lm_indic-or_wikisource_filtered
# 7.60e-05 - lm_pt_opus100
# 7.50e-05 - lm_en_pseudocrawl-filtered_500_www_asiaone_com_singapore
# 7.50e-05 - lm_zhs_pseudocrawl-filtered_674_ai_baidu_com
# 7.49e-05 - lm_zhs_ted_talks_iwslt
# 7.36e-05 - lm_pt_wikibooks_filtered
# 7.33e-05 - lm_vi_ted_talks_iwslt
# 7.27e-05 - lm_indic-ta_opus100
# 7.13e-05 - lm_eu_opus100
# 7.07e-05 - lm_ar_wiktionary_filtered
# 7.03e-05 - lm_indic-ta_pib
# 6.75e-05 - lm_ca_parlament_parla
# 6.61e-05 - lm_fr_wikivoyage_filtered
# 6.25e-05 - lm_en_pseudocrawl-filtered_339_www_actasanitaria_com
# 6.25e-05 - lm_en_pseudocrawl-filtered_488_dailyvanity_sg
# 6.10e-05 - lm_zhs_wikinews_filtered
# 5.85e-05 - lm_vi_opus100
# 5.79e-05 - lm_indic-mr_pib
# 5.72e-05 - lm_ca_opus100
# 5.61e-05 - lm_indic-ml_open_subtitles
# 5.46e-05 - lm_es_wikivoyage_filtered
# 5.36e-05 - lm_indic-bn_open_subtitles
# 5.33e-05 - lm_indic-hi_wikibooks_filtered
# 5.27e-05 - lm_nigercongo-rw_aggregated
# 5.24e-05 - lm_id_opus100
# 5.12e-05 - lm_indic-ml_wiktionary_filtered
# 4.98e-05 - lm_indic-pa_pib
# 4.77e-05 - lm_ar_labr
# 4.76e-05 - lm_indic-bn_pib
# 4.74e-05 - lm_ar_wikinews_filtered
# 4.53e-05 - lm_indic-or_pib
# 4.41e-05 - lm_zhs_wikibooks_filtered
# 4.37e-05 - lm_zhs_wikiversity_filtered
# 4.35e-05 - lm_fr_wikiquote_filtered
# 4.33e-05 - lm_es_wikinews_filtered
# 4.09e-05 - lm_pt_wikiversity_filtered
# 4.08e-05 - lm_eu_wikisource_filtered
# 3.92e-05 - lm_id_ted_talks_iwslt
# 3.81e-05 - lm_eu_open_subtitles
# 3.78e-05 - lm_ar_habibi
# 3.50e-05 - lm_es_qedcorpus
# 3.43e-05 - lm_indic-or_odiencorp
# 3.14e-05 - lm_ca_tv3_parla
# 3.09e-05 - lm_id_wikibooks_filtered
# 3.02e-05 - lm_indic-gu_opus100
# 3.01e-05 - lm_indic-gu_pib
# 2.96e-05 - lm_indic-bn_bengali_question_answering
# 2.96e-05 - lm_eu_wiktionary_filtered
# 2.85e-05 - lm_es_scielo
# 2.84e-05 - lm_pt_wikiquote_filtered
# 2.72e-05 - lm_es_wikiquote_filtered
# 2.68e-05 - lm_zhs_wikivoyage_filtered
# 2.65e-05 - lm_fr_ester
# 2.63e-05 - lm_es_wikiversity_filtered
# 2.59e-05 - lm_indic-te_pib
# 2.56e-05 - lm_indic-ml_pib
# 2.55e-05 - lm_ca_open_subtitles
# 2.44e-05 - lm_indic-ta_wikinews_filtered
# 2.12e-05 - lm_indic-pa_wiktionary_filtered
# 2.09e-05 - lm_ca_wikinews_filtered
# 1.95e-05 - lm_id_wikimedia_filtered
# 1.94e-05 - lm_pt_qedcorpus
# 1.81e-05 - lm_nigercongo-xh_aggregated
# 1.80e-05 - lm_zhs_wikiquote_filtered
# 1.77e-05 - lm_ar_wikibooks_filtered
# 1.74e-05 - lm_indic-hi_ted_talks_iwslt
# 1.66e-05 - lm_ca_wikibooks_filtered
# 1.63e-05 - lm_indic-bn_wiktionary_filtered
# 1.59e-05 - lm_en_bloom
# 1.57e-05 - lm_nigercongo-ig_aggregated
# 1.56e-05 - lm_eu_wikibooks_filtered
# 1.53e-05 - lm_ar_wikiquote_filtered
# 1.52e-05 - lm_pt_wikivoyage_filtered
# 1.45e-05 - lm_indic-as_opus100
# 1.40e-05 - lm_indic-as_samanantar
# 1.39e-05 - lm_vi_wikivoyage_filtered
# 1.38e-05 - lm_vi_vinbigdata_asr_vlsp_2020
# 1.33e-05 - lm_ar_qedcorpus
# 1.29e-05 - lm_ca_ted_talks_iwslt
# 1.28e-05 - lm_ca_wikiquote_filtered
# 1.19e-05 - lm_indic-hi_open_subtitles
# 1.12e-05 - lm_nigercongo-zu_aggregated
# 1.06e-05 - lm_en_odiencorp
# 1.04e-05 - lm_fr_qedcorpus
# 9.80e-06 - lm_ar_arabench
# 9.36e-06 - lm_nigercongo-sn_aggregated
# 9.17e-06 - lm_indic-bn_wikivoyage_filtered
# 9.16e-06 - lm_indic-ur_wiktionary_filtered
# 9.06e-06 - lm_indic-ta_ted_talks_iwslt
# 8.39e-06 - lm_indic-ta_wikiquote_filtered
# 8.33e-06 - lm_indic-te_wikibooks_filtered
# 8.10e-06 - lm_id_recibrew
# 7.41e-06 - lm_indic-pa_opus100
# 7.22e-06 - lm_indic-mr_ted_talks_iwslt
# 6.96e-06 - lm_indic-bn_ted_talks_iwslt
# 6.79e-06 - lm_zhs_qedcorpus
# 6.69e-06 - lm_ar_wikiversity_filtered
# 6.67e-06 - lm_indic-ta_wikibooks_filtered
# 6.65e-06 - lm_indic-hi_wikiquote_filtered
# 6.33e-06 - lm_indic-te_opus100
# 6.23e-06 - lm_indic-ur_wikibooks_filtered
# 5.97e-06 - lm_indic-hi_qedcorpus
# 5.78e-06 - lm_zht_qedcorpus
# 5.67e-06 - lm_nigercongo-lg_aggregated
# 5.56e-06 - lm_vi_wikiquote_filtered
# 5.35e-06 - lm_ca_teca
# 4.90e-06 - lm_id_indonli
# 4.63e-06 - lm_indic-ur_ted_talks_iwslt
# 4.41e-06 - lm_nigercongo-wo_aggregated
# 4.28e-06 - lm_indic-bn_bangla_sentiment_classification_datasets
# 4.03e-06 - lm_indic-ml_wikiquote_filtered
# 4.02e-06 - lm_nigercongo-rn_aggregated
# 3.88e-06 - lm_indic-ta_open_subtitles
# 3.66e-06 - lm_indic-mr_wikibooks_filtered
# 3.55e-06 - lm_ca_enriched_conllu_ancora_for_ml_training
# 3.49e-06 - lm_indic-bn_wikibooks_filtered
# 3.49e-06 - lm_ca_wikimedia_filtered
# 3.48e-06 - lm_en_scielo
# 3.19e-06 - lm_ca_viquiquad
# 3.11e-06 - lm_id_wikiquote_filtered
# 3.02e-06 - lm_ca_vilaquad
# 2.81e-06 - lm_indic-mr_opus100
# 2.78e-06 - lm_indic-ur_open_subtitles
# 2.75e-06 - lm_indic-ml_ted_talks_iwslt
# 2.73e-06 - lm_indic-gu_wikiquote_filtered
# 2.71e-06 - lm_indic-mr_wiktionary_filtered
# 2.63e-06 - lm_indic-hi_wikivoyage_filtered
# 2.59e-06 - lm_indic-te_open_subtitles
# 2.50e-06 - lm_fr_bloom
# 2.47e-06 - lm_nigercongo-fon_aggregated
# 2.46e-06 - lm_indic-ml_wikibooks_filtered
# 2.45e-06 - lm_indic-ta_mkb
# 2.42e-06 - lm_es_bloom
# 2.42e-06 - lm_nigercongo-nso_aggregated
# 2.28e-06 - lm_indic-te_wikiquote_filtered
# 2.09e-06 - lm_vi_vietnamese_students_feedback
# 2.08e-06 - lm_pt_wikimedia_filtered
# 2.04e-06 - lm_nigercongo-ln_aggregated
# 2.04e-06 - lm_indic-gu_ted_talks_iwslt
# 2.00e-06 - lm_indic-gu_mkb
# 1.97e-06 - lm_indic-gu_wiktionary_filtered
# 1.94e-06 - lm_indic-te_ted_talks_iwslt
# 1.94e-06 - lm_eu_ted_talks_iwslt
# 1.92e-06 - lm_nigercongo-tn_aggregated
# 1.88e-06 - lm_indic-mr_mkb
# 1.88e-06 - lm_indic-ml_mkb
# 1.83e-06 - lm_indic-kn_opus100
# 1.81e-06 - lm_indic-kn_wikiquote_filtered
# 1.74e-06 - lm_indic-bn_mkb
# 1.67e-06 - lm_indic-hi_wikiversity_filtered
# 1.62e-06 - lm_indic-or_opus100
# 1.60e-06 - lm_indic-hi_mkb
# 1.58e-06 - lm_indic-te_mkb
# 1.55e-06 - lm_nigercongo-tw_aggregated
# 1.50e-06 - lm_indic-kn_ted_talks_iwslt
# 1.49e-06 - lm_nigercongo-ny_aggregated
# 1.21e-06 - lm_indic-bn_bloom
# 1.13e-06 - lm_indic-ur_wikiquote_filtered
# 9.77e-07 - lm_eu_wikiquote_filtered
# 9.43e-07 - lm_nigercongo-st_aggregated
# 9.07e-07 - lm_nigercongo-ts_aggregated
# 8.99e-07 - lm_ca_sts_ca
# 8.38e-07 - lm_nigercongo-ak_aggregated
# 8.25e-07 - lm_indic-mr_wikiquote_filtered
# 6.81e-07 - lm_pt_bloom
# 6.77e-07 - lm_vi_uit_vsmec
# 5.93e-07 - lm_id_bloom
# 4.82e-07 - lm_nigercongo-bm_aggregated
# 4.53e-07 - lm_nigercongo-ki_aggregated
# 2.70e-07 - lm_ca_xquad_ca
# 2.45e-07 - lm_indic-pa_wikibooks_filtered
# 2.37e-07 - lm_indic-or_mkb
# 2.24e-07 - lm_nigercongo-tum_aggregated
# 2.20e-07 - lm_indic-ur_mkb
# 1.83e-07 - lm_id_indonesian_frog_storytelling_corpus
# 1.21e-07 - lm_indic-hi_bloom
# 1.21e-07 - lm_indic-hi_wikimedia_filtered
# 1.10e-07 - lm_en_book_dash_books
# 6.60e-08 - lm_indic-ml_bloom
# 6.47e-08 - lm_indic-ta_bloom
# 3.59e-08 - lm_indic-mr_bloom
# 2.55e-08 - lm_indic-as_ted_talks_iwslt
# 2.54e-08 - lm_fr_book_dash_books
# 2.01e-08 - lm_indic-gu_bloom
# 1.52e-08 - lm_indic-pa_bloom
# 1.51e-08 - lm_vi_bloom
# 1.38e-08 - lm_indic-ur_bloom
# 5.22e-09 - lm_indic-as_wiktionary_filtered
# 3.98e-09 - lm_indic-or_bloom
# 3.30e-09 - lm_indic-pa_ted_talks_iwslt
# 1.84e-09 - lm_zhs_bloom
# 1.22e-09 - lm_indic-kn_bloom
# 4.55e-10 - lm_indic-te_bloom

# %%
orig_lang
# Out:
# {'du_reader': 'zh',
#  'multi_un_2': 'zh',
#  'open_subtitles': 'zh',
#  'opus100': 'zh',
#  'project_gutenberg': 'zh',
#  'ted_talks_iwslt': 'zh',
#  'uncorpus': 'zh',
#  'wudaocorpora': 'zh',
#  'multilingual_knowledge_questions_answers': 'zh-TW',
#  'qedcorpus': 'zht',
#  'bloom': 'zh',
#  'wikipedia': 'zh-tw',
#  'wikivoyage_filtered': 'zh',
#  'wiktionary_filtered': 'zh',
#  'wikiversity_filtered': 'zh',
#  'wikinews_filtered': 'zh',
#  'wikibooks_filtered': 'zh',
#  'wikiquote_filtered': 'zh'}

# %%
import json
json.dump(tokenization_ratios, open("bigscience_data_v1_ratios_800GB_zh_aggregated.json", "w", encoding="utf-8"), indent=2)

# %%
lang_to_target_alphas = {}

tok_total = int(30e9)

lang_to_target_alpha_ratios = {}
for ln, keep_size in lang_to_target.items():
    lang_to_target_alpha_ratios[ln] = (keep_size / target_size) ** 0.3

alpha_tot_ratios = sum(lang_to_target_alpha_ratios.values())
for ln, r in lang_to_target_alpha_ratios.items():
    ln_ratio = r / alpha_tot_ratios
    print(f"{ln:15s} - {ln_ratio:.2e} %")
    lang_to_target_alphas[ln] = ln_ratio * tok_total
# Out:
# en              - 6.34e-02 %
# zhs             - 6.34e-02 %
# code            - 6.34e-02 %
# fr              - 6.34e-02 %
# es              - 6.33e-02 %
# ar              - 5.69e-02 %
# id              - 5.24e-02 %
# vi              - 4.68e-02 %
# indic-hi        - 4.40e-02 %
# pt              - 4.18e-02 %
# indic-bn        - 3.96e-02 %
# ca              - 3.70e-02 %
# indic-ta        - 3.31e-02 %
# indic-ml        - 2.73e-02 %
# indic-te        - 2.69e-02 %
# indic-kn        - 2.55e-02 %
# indic-ne        - 2.43e-02 %
# indic-ur        - 2.38e-02 %
# indic-mr        - 2.33e-02 %
# indic-pa        - 2.21e-02 %
# indic-gu        - 2.12e-02 %
# eu              - 2.05e-02 %
# indic-or        - 1.71e-02 %
# zht             - 1.57e-02 %
# indic-as        - 1.13e-02 %
# nigercongo-sw   - 1.07e-02 %
# nigercongo-yo   - 7.18e-03 %
# nigercongo-rw   - 6.16e-03 %
# nigercongo-xh   - 4.47e-03 %
# nigercongo-ig   - 4.28e-03 %
# nigercongo-zu   - 3.87e-03 %
# nigercongo-sn   - 3.67e-03 %
# nigercongo-lg   - 3.16e-03 %
# nigercongo-wo   - 2.93e-03 %
# nigercongo-rn   - 2.85e-03 %
# nigercongo-fon  - 2.46e-03 %
# nigercongo-nso  - 2.44e-03 %
# nigercongo-ln   - 2.32e-03 %
# nigercongo-tn   - 2.28e-03 %
# nigercongo-tw   - 2.14e-03 %
# nigercongo-ny   - 2.12e-03 %
# nigercongo-st   - 1.84e-03 %
# nigercongo-ts   - 1.82e-03 %
# nigercongo-ak   - 1.78e-03 %
# nigercongo-bm   - 1.51e-03 %
# nigercongo-ki   - 1.48e-03 %
# nigercongo-tum  - 1.20e-03 %

# %%
tokenization_ratios = []

total_size = 0

for lang, sizes in lang_to_sizes.items():
    ln_target_size = lang_to_target_alphas[lang]
    current_size = 0
    prev_size = 0
    num_dsets = len(sizes)
    for i, (name, size) in enumerate(sorted(sizes, key=lambda x:x[1])):
        if current_size < ln_target_size:
            add_size = min(size - prev_size, (ln_target_size - current_size) // (num_dsets - i) + 1)
            current_size += add_size * (num_dsets - i)
            prev_size += add_size
        tokenization_ratios += [
            {
                'dataset_path': f"bigscience-catalogue-lm-data/lm_{lang}_{name}",
                'is_catalogue': True,
                'ratio': prev_size / target_size
            }]
    total_size += current_size

for dct in sorted(tokenization_ratios, key=lambda dct: dct['ratio'], reverse=True):
    print(f"{dct['ratio']:.2e} - {dct['dataset_path'].split('/')[1]}")
# Out:
# 1.16e-03 - lm_code_stackexchange
# 1.16e-03 - lm_code_github-no-gpl
# 8.89e-04 - lm_indic-ne_unsupervised_cross_lingual_representation_learning_at_scale
# 5.72e-04 - lm_zh-tw_wikipedia
# 5.72e-04 - lm_zh-cn_wikipedia
# 3.30e-04 - lm_nigercongo-sw_lm_nigercongo-sw_aggregated
# 2.89e-04 - lm_zh_wiktionary_filtered
# 2.89e-04 - lm_zh_open_subtitles
# 2.89e-04 - lm_zh_multi_un_2
# 2.89e-04 - lm_zh_uncorpus
# 2.89e-04 - lm_zh_du_reader
# 2.89e-04 - lm_zh_wudaocorpora
# 2.77e-04 - lm_indic-as_wikisource_filtered
# 2.46e-04 - lm_eu_wikipedia
# 2.46e-04 - lm_eu_bsbasque
# 2.21e-04 - lm_indic-hi_wikipedia
# 2.21e-04 - lm_indic-hi_wikisource_filtered
# 2.21e-04 - lm_indic-hi_samanantar
# 2.21e-04 - lm_indic-hi_iitb_english_hindi_corpus
# 2.21e-04 - lm_indic-hi_indic_nlp_corpus
# 2.12e-04 - lm_indic-bn_opus100
# 2.12e-04 - lm_indic-bn_wikipedia
# 2.12e-04 - lm_indic-bn_samanantar
# 2.12e-04 - lm_indic-bn_indic_nlp_corpus
# 2.12e-04 - lm_indic-bn_wikisource_filtered
# 2.12e-04 - lm_indic-bn_bangla_lm
# 2.12e-04 - lm_indic-kn_wikipedia
# 2.12e-04 - lm_indic-kn_wikisource_filtered
# 2.12e-04 - lm_indic-kn_samanantar
# 2.12e-04 - lm_indic-kn_indic_nlp_corpus
# 2.09e-04 - lm_zh_project_gutenberg
# 2.05e-04 - lm_indic-te_wikisource_filtered
# 2.05e-04 - lm_indic-te_wikipedia
# 2.05e-04 - lm_indic-te_samanantar
# 2.05e-04 - lm_indic-te_indic_nlp_corpus
# 2.02e-04 - lm_indic-ta_wiktionary_filtered
# 2.02e-04 - lm_indic-ta_wikipedia
# 2.02e-04 - lm_indic-ta_samanantar
# 2.02e-04 - lm_indic-ta_wikisource_filtered
# 2.02e-04 - lm_indic-ta_indic_nlp_corpus
# 1.93e-04 - lm_indic-mr_wikipedia
# 1.93e-04 - lm_indic-mr_wikisource_filtered
# 1.93e-04 - lm_indic-mr_samanantar
# 1.93e-04 - lm_indic-mr_indic_nlp_corpus
# 1.88e-04 - lm_indic-pa_wikipedia
# 1.88e-04 - lm_indic-pa_samanantar
# 1.88e-04 - lm_indic-pa_indic_nlp_corpus
# 1.86e-04 - lm_indic-gu_wikisource_filtered
# 1.86e-04 - lm_indic-gu_samanantar
# 1.86e-04 - lm_indic-gu_indic_nlp_corpus
# 1.71e-04 - lm_indic-ml_opus100
# 1.71e-04 - lm_indic-ml_wikisource_filtered
# 1.71e-04 - lm_indic-ml_wikipedia
# 1.71e-04 - lm_indic-ml_samanantar
# 1.71e-04 - lm_indic-ml_indic_nlp_corpus
# 1.67e-04 - lm_indic-pa_wikisource_filtered
# 1.53e-04 - lm_indic-ur_opus100
# 1.53e-04 - lm_indic-ur_wikipedia
# 1.53e-04 - lm_indic-ur_leipzig_wortschatz_urdu_newscrawl_2016_sentences
# 1.53e-04 - lm_indic-ur_urdu-monolingual-corpus
# 1.53e-04 - lm_indic-ur_leipzig_wortschatz_urdu-pk_web_2019_sentences
# 1.50e-04 - lm_id_indosum
# 1.50e-04 - lm_id_pseudocrawl-filtered_512_kumparan_com
# 1.50e-04 - lm_id_indonesian_news_corpus
# 1.50e-04 - lm_id_wiktionary_filtered
# 1.50e-04 - lm_id_pseudocrawl-filtered_545_www_detik_com
# 1.50e-04 - lm_id_wikipedia
# 1.50e-04 - lm_id_pseudocrawl-filtered_549_www_cnnindonesia_com
# 1.50e-04 - lm_id_pseudocrawl-filtered_572_tirto_id
# 1.50e-04 - lm_id_open_subtitles
# 1.50e-04 - lm_id_indonesian_news_articles_2017
# 1.50e-04 - lm_id_indo4b
# 1.47e-04 - lm_indic-or_samanantar
# 1.47e-04 - lm_indic-or_indic_nlp_corpus
# 1.46e-04 - lm_indic-gu_wikipedia
# 1.45e-04 - lm_ca_wiktionary_filtered
# 1.45e-04 - lm_ca_catalan_government_crawling
# 1.45e-04 - lm_ca_tecla
# 1.45e-04 - lm_ca_wikipedia
# 1.45e-04 - lm_ca_catalan_general_crawling
# 1.45e-04 - lm_ca_catalan_textual_corpus
# 1.42e-04 - lm_indic-hi_pib
# 1.35e-04 - lm_vi_wiktionary_filtered
# 1.35e-04 - lm_vi_wikisource_filtered
# 1.35e-04 - lm_vi_open_subtitles
# 1.35e-04 - lm_vi_vntq_corpus_big
# 1.35e-04 - lm_vi_vinbigdata_mt_vlsp_2020
# 1.35e-04 - lm_vi_wikipedia
# 1.35e-04 - lm_vi_vietai_sat
# 1.35e-04 - lm_vi_vinbigdata_monolingual_vlsp_2020
# 1.35e-04 - lm_vi_binhvq_news_corpus
# 1.34e-04 - lm_vi_vietnamese_poetry
# 1.28e-04 - lm_pt_project_gutenberg
# 1.28e-04 - lm_pt_ted_talks_iwslt
# 1.28e-04 - lm_pt_wiktionary_filtered
# 1.28e-04 - lm_pt_wikisource_filtered
# 1.28e-04 - lm_pt_the_pile_europarl
# 1.28e-04 - lm_pt_scielo
# 1.28e-04 - lm_pt_wikipedia
# 1.28e-04 - lm_pt_open_subtitles
# 1.28e-04 - lm_pt_brwac
# 1.24e-04 - lm_fr_opus100
# 1.24e-04 - lm_fr_wikiversity_filtered
# 1.24e-04 - lm_fr_wikibooks_filtered
# 1.24e-04 - lm_fr_the_pile_europarl
# 1.24e-04 - lm_fr_pseudocrawl-filtered_599_fr_globalvoices_org
# 1.24e-04 - lm_fr_pseudocrawl-filtered_530_www_mediapart_fr
# 1.24e-04 - lm_fr_bnl_historical_newspapers
# 1.24e-04 - lm_fr_project_gutenberg
# 1.24e-04 - lm_fr_wiktionary_filtered
# 1.24e-04 - lm_fr_multi_un_2
# 1.24e-04 - lm_fr_wikipedia
# 1.24e-04 - lm_fr_open_subtitles
# 1.24e-04 - lm_fr_pseudocrawl-filtered_550_www_lemonde_fr
# 1.24e-04 - lm_fr_uncorpus
# 1.24e-04 - lm_fr_wikisource_filtered
# 1.24e-04 - lm_fr_hal_archives_ouvertes
# 1.17e-04 - lm_indic-te_wiktionary_filtered
# 1.16e-04 - lm_indic-hi_wiktionary_filtered
# 1.16e-04 - lm_ca_wikisource_filtered
# 1.15e-04 - lm_zh_opus100
# 1.13e-04 - lm_pt_wikinews_filtered
# 1.13e-04 - lm_indic-hi_opus100
# 1.10e-04 - lm_id_wikisource_filtered
# 1.07e-04 - lm_ar_opus100
# 1.07e-04 - lm_ar_ted_talks_iwslt
# 1.07e-04 - lm_ar_kalimat
# 1.07e-04 - lm_ar_osac
# 1.07e-04 - lm_ar_brad_2
# 1.07e-04 - lm_ar_ksucca
# 1.07e-04 - lm_ar_sanad
# 1.07e-04 - lm_ar_tashkeela
# 1.07e-04 - lm_ar_wikisource_filtered
# 1.07e-04 - lm_ar_pseudocrawl-filtered_595_mawdoo3_com
# 1.07e-04 - lm_ar_multi_un_2
# 1.07e-04 - lm_ar_wikipedia
# 1.07e-04 - lm_ar_open_subtitles
# 1.07e-04 - lm_ar_uncorpus
# 1.07e-04 - lm_ar_openiti_proc
# 1.07e-04 - lm_ar_arabic_billion_words
# 1.07e-04 - lm_ar_openiti
# 1.02e-04 - lm_fr_ted_talks_iwslt
# 1.02e-04 - lm_ca_ca_text_corpus
# 1.01e-04 - lm_vi_data_on_covid_19_news_coverage_in_vietnam
# 1.01e-04 - lm_en_wikinews_filtered
# 1.01e-04 - lm_en_qedcorpus
# 1.01e-04 - lm_en_india_news_headlines_dataset
# 1.01e-04 - lm_en_wikivoyage_filtered
# 1.01e-04 - lm_en_wikiversity_filtered
# 1.01e-04 - lm_en_the_pile_europarl
# 1.01e-04 - lm_en_royal_society_corpus
# 1.01e-04 - lm_en_wikiquote_filtered
# 1.01e-04 - lm_en_wikibooks_filtered
# 1.01e-04 - lm_en_multi_un_2
# 1.01e-04 - lm_en_wiktionary_filtered
# 1.01e-04 - lm_en_uncorpus
# 1.01e-04 - lm_en_no_code_stackexchange
# 1.01e-04 - lm_en_wikipedia
# 1.01e-04 - lm_en_open_subtitles
# 1.01e-04 - lm_en_project_gutenberg
# 1.01e-04 - lm_en_the_pile_uspto
# 1.01e-04 - lm_en_s2orc_ai2_abstracts
# 1.01e-04 - lm_en_pmc
# 1.01e-04 - lm_en_arxiv
# 1.01e-04 - lm_en_s2orc_ai2_pdf_parses
# 9.85e-05 - lm_en_a_million_news_headlines_abc_australia
# 9.06e-05 - lm_indic-or_wiktionary_filtered
# 8.99e-05 - lm_vi_wikibooks_filtered
# 8.83e-05 - lm_indic-as_wikipedia
# 8.75e-05 - lm_nigercongo-yo_lm_nigercongo-yo_aggregated
# 8.38e-05 - lm_indic-or_wikipedia
# 8.32e-05 - lm_fr_wikinews_filtered
# 8.19e-05 - lm_en_ted_talks_iwslt
# 8.01e-05 - lm_indic-ur_pib
# 7.75e-05 - lm_indic-kn_wiktionary_filtered
# 7.63e-05 - lm_indic-or_wikisource_filtered
# 7.60e-05 - lm_pt_opus100
# 7.49e-05 - lm_zh_ted_talks_iwslt
# 7.36e-05 - lm_pt_wikibooks_filtered
# 7.33e-05 - lm_vi_ted_talks_iwslt
# 7.27e-05 - lm_indic-ta_opus100
# 7.13e-05 - lm_eu_opus100
# 7.07e-05 - lm_ar_wiktionary_filtered
# 7.03e-05 - lm_indic-ta_pib
# 6.75e-05 - lm_ca_parlament_parla
# 6.61e-05 - lm_fr_wikivoyage_filtered
# 6.10e-05 - lm_zh_wikinews_filtered
# 5.85e-05 - lm_vi_opus100
# 5.79e-05 - lm_indic-mr_pib
# 5.72e-05 - lm_ca_opus100
# 5.61e-05 - lm_indic-ml_open_subtitles
# 5.36e-05 - lm_indic-bn_open_subtitles
# 5.33e-05 - lm_indic-hi_wikibooks_filtered
# 5.27e-05 - lm_nigercongo-rw_lm_nigercongo-rw_aggregated
# 5.24e-05 - lm_id_opus100
# 5.12e-05 - lm_indic-ml_wiktionary_filtered
# 4.98e-05 - lm_indic-pa_pib
# 4.77e-05 - lm_ar_labr
# 4.76e-05 - lm_indic-bn_pib
# 4.74e-05 - lm_ar_wikinews_filtered
# 4.53e-05 - lm_indic-or_pib
# 4.41e-05 - lm_zh_wikibooks_filtered
# 4.37e-05 - lm_zh_wikiversity_filtered
# 4.35e-05 - lm_fr_wikiquote_filtered
# 4.09e-05 - lm_pt_wikiversity_filtered
# 4.08e-05 - lm_eu_wikisource_filtered
# 3.92e-05 - lm_id_ted_talks_iwslt
# 3.81e-05 - lm_eu_open_subtitles
# 3.78e-05 - lm_ar_habibi
# 3.43e-05 - lm_indic-or_odiencorp
# 3.14e-05 - lm_ca_tv3_parla
# 3.09e-05 - lm_id_wikibooks_filtered
# 3.02e-05 - lm_indic-gu_opus100
# 3.01e-05 - lm_indic-gu_pib
# 2.96e-05 - lm_indic-bn_bengali_question_answering
# 2.96e-05 - lm_eu_wiktionary_filtered
# 2.84e-05 - lm_pt_wikiquote_filtered
# 2.68e-05 - lm_zh_wikivoyage_filtered
# 2.65e-05 - lm_fr_ester
# 2.59e-05 - lm_indic-te_pib
# 2.56e-05 - lm_indic-ml_pib
# 2.55e-05 - lm_ca_open_subtitles
# 2.44e-05 - lm_indic-ta_wikinews_filtered
# 2.12e-05 - lm_indic-pa_wiktionary_filtered
# 2.09e-05 - lm_ca_wikinews_filtered
# 1.95e-05 - lm_id_wikimedia_filtered
# 1.94e-05 - lm_pt_qedcorpus
# 1.85e-05 - lm_es_wikiversity_filtered
# 1.85e-05 - lm_es_wikiquote_filtered
# 1.85e-05 - lm_es_scielo
# 1.85e-05 - lm_es_qedcorpus
# 1.85e-05 - lm_es_wikinews_filtered
# 1.85e-05 - lm_es_wikivoyage_filtered
# 1.85e-05 - lm_es_ted_talks_iwslt
# 1.85e-05 - lm_es_opus100
# 1.85e-05 - lm_es_wikibooks_filtered
# 1.85e-05 - lm_es_pseudocrawl-filtered_244_www_df_cl
# 1.85e-05 - lm_es_pseudocrawl-filtered_62_www_lapagina_com_sv
# 1.85e-05 - lm_es_pseudocrawl-filtered_280_salamancartvaldia_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_32_www_elexpresso_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_30_www_radiocable_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_158_www_diariodeleon_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_219_www_aguasresiduales_info
# 1.85e-05 - lm_es_pseudocrawl-filtered_153_financialfood_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_56_www_eluniverso_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_207_elimpulso_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_125_www_noticiasde_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_420_www_retema_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_374_www_talcualdigital_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_182_correodelsur_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_118_www_elheraldo_hn
# 1.85e-05 - lm_es_pseudocrawl-filtered_386_www_prensalibre_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_233_www_dinero_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_254_diario_mx
# 1.85e-05 - lm_es_pseudocrawl-filtered_294_www_laopinion_com_co
# 1.85e-05 - lm_es_project_gutenberg
# 1.85e-05 - lm_es_pseudocrawl-filtered_23_www_elconfidencialdigital_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_286_www_nacion_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_422_www_formulatv_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_417_www_radiolaprimerisima_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_406_www_americaeconomia_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_367_elcorreoweb_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_276_radio_uchile_cl
# 1.85e-05 - lm_es_pseudocrawl-filtered_231_ojo_pe
# 1.85e-05 - lm_es_pseudocrawl-filtered_223_www_eltambor_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_325_www_laprensa_hn
# 1.85e-05 - lm_es_pseudocrawl-filtered_250_www_cooperativa_cl
# 1.85e-05 - lm_es_pseudocrawl-filtered_246_www_eldiarionuevodia_com_ar
# 1.85e-05 - lm_es_pseudocrawl-filtered_34_www_losandes_com_ar
# 1.85e-05 - lm_es_the_pile_europarl
# 1.85e-05 - lm_es_pseudocrawl-filtered_277_www_entornointeligente_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_172_www_rionegro_com_ar
# 1.85e-05 - lm_es_pseudocrawl-filtered_167_www_ambientum_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_21_www_elperiodicodearagon_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_116_www_latribuna_hn
# 1.85e-05 - lm_es_pseudocrawl-filtered_53_www_expreso_ec
# 1.85e-05 - lm_es_pseudocrawl-filtered_404_www_telam_com_ar
# 1.85e-05 - lm_es_pseudocrawl-filtered_315_lasillavacia_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_431_www_elperiodicoextremadura_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_91_www_diario26_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_392_www_muypymes_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_169_www_el_carabobeno_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_320_www_paginasiete_bo
# 1.85e-05 - lm_es_pseudocrawl-filtered_90_peru_com
# 1.85e-05 - lm_es_wiktionary_filtered
# 1.85e-05 - lm_es_pseudocrawl-filtered_232_tn_com_ar
# 1.85e-05 - lm_es_pseudocrawl-filtered_44_ladiaria_com_uy
# 1.85e-05 - lm_es_pseudocrawl-filtered_220_www_vanguardia_com_mx
# 1.85e-05 - lm_es_pseudocrawl-filtered_130_www_elperiodicomediterraneo_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_376_www_elpopular_com_ar
# 1.85e-05 - lm_es_pseudocrawl-filtered_229_www_expansion_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_253_www_debate_com_mx
# 1.85e-05 - lm_es_pseudocrawl-filtered_28_www_fayerwayer_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_78_www_listindiario_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_359_www_efeverde_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_256_www_laprovincia_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_226_www_ole_com_ar
# 1.85e-05 - lm_es_pseudocrawl-filtered_317_diariocorreo_pe
# 1.85e-05 - lm_es_pseudocrawl-filtered_165_www_ticbeat_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_401_www_elperiodicodemexico_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_675_www_elespectador_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_257_www_diaridetarragona_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_213_www_hola_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_203_www_que_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_405_www_emol_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_67_www_elpais_cr
# 1.85e-05 - lm_es_pseudocrawl-filtered_430_www_eldiario_ec
# 1.85e-05 - lm_es_pseudocrawl-filtered_324_gestion_pe
# 1.85e-05 - lm_es_pseudocrawl-filtered_288_www_marca_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_71_www_rtve_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_381_www_cuartopoder_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_209_misionesonline_net
# 1.85e-05 - lm_es_pseudocrawl-filtered_86_www_motorpasion_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_373_www_farodevigo_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_287_www_cibercuba_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_249_www_telecinco_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_79_www_laopiniondemurcia_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_299_www_lne_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_641_es_globalvoices_org
# 1.85e-05 - lm_es_pseudocrawl-filtered_58_www_levante_emv_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_157_www_elsoldemexico_com_mx
# 1.85e-05 - lm_es_pseudocrawl-filtered_237_www_cronista_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_245_www_noticiasdenavarra_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_518_www_elcolombiano_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_248_www_telesurtv_net
# 1.85e-05 - lm_es_wikisource_filtered
# 1.85e-05 - lm_es_pseudocrawl-filtered_136_valenciaplaza_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_103_www_elmostrador_cl
# 1.85e-05 - lm_es_pseudocrawl-filtered_189_www_eleconomista_com_mx
# 1.85e-05 - lm_es_pseudocrawl-filtered_429_cadenaser_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_146_www_perfil_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_215_www_lainformacion_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_198_www_eleconomista_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_409_www_proceso_com_mx
# 1.85e-05 - lm_es_pseudocrawl-filtered_263_www_lasexta_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_354_www_lagaceta_com_ar
# 1.85e-05 - lm_es_pseudocrawl-filtered_181_noticiassin_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_267_www_elperiodico_com_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_211_www_elcomercio_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_349_www_eltiempo_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_333_www_elmundo_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_255_elcomercio_pe
# 1.85e-05 - lm_es_pseudocrawl-filtered_63_www_lanacion_com_ar
# 1.85e-05 - lm_es_pseudocrawl-filtered_424_www_lavanguardia_com
# 1.85e-05 - lm_es_multi_un_2
# 1.85e-05 - lm_es_pseudocrawl-filtered_20_www_clarin_com
# 1.85e-05 - lm_es_wikipedia
# 1.85e-05 - lm_es_pseudocrawl-filtered_341_es_cointelegraph_com
# 1.85e-05 - lm_es_pseudocrawl-filtered_396_www_eldiario_es
# 1.85e-05 - lm_es_pseudocrawl-filtered_100_www_aporrea_org
# 1.85e-05 - lm_es_uncorpus
# 1.85e-05 - lm_es_open_subtitles
# 1.81e-05 - lm_nigercongo-xh_lm_nigercongo-xh_aggregated
# 1.80e-05 - lm_zh_wikiquote_filtered
# 1.77e-05 - lm_ar_wikibooks_filtered
# 1.74e-05 - lm_indic-hi_ted_talks_iwslt
# 1.66e-05 - lm_ca_wikibooks_filtered
# 1.63e-05 - lm_indic-bn_wiktionary_filtered
# 1.59e-05 - lm_en_bloom
# 1.57e-05 - lm_nigercongo-ig_lm_nigercongo-ig_aggregated
# 1.56e-05 - lm_eu_wikibooks_filtered
# 1.53e-05 - lm_ar_wikiquote_filtered
# 1.52e-05 - lm_pt_wikivoyage_filtered
# 1.45e-05 - lm_indic-as_opus100
# 1.40e-05 - lm_indic-as_samanantar
# 1.39e-05 - lm_vi_wikivoyage_filtered
# 1.38e-05 - lm_vi_vinbigdata_asr_vlsp_2020
# 1.33e-05 - lm_ar_qedcorpus
# 1.29e-05 - lm_ca_ted_talks_iwslt
# 1.28e-05 - lm_ca_wikiquote_filtered
# 1.19e-05 - lm_indic-hi_open_subtitles
# 1.12e-05 - lm_nigercongo-zu_lm_nigercongo-zu_aggregated
# 1.06e-05 - lm_en_odiencorp
# 1.04e-05 - lm_fr_qedcorpus
# 9.80e-06 - lm_ar_arabench
# 9.36e-06 - lm_nigercongo-sn_lm_nigercongo-sn_aggregated
# 9.17e-06 - lm_indic-bn_wikivoyage_filtered
# 9.16e-06 - lm_indic-ur_wiktionary_filtered
# 9.06e-06 - lm_indic-ta_ted_talks_iwslt
# 8.39e-06 - lm_indic-ta_wikiquote_filtered
# 8.33e-06 - lm_indic-te_wikibooks_filtered
# 8.10e-06 - lm_id_recibrew
# 7.41e-06 - lm_indic-pa_opus100
# 7.22e-06 - lm_indic-mr_ted_talks_iwslt
# 6.96e-06 - lm_indic-bn_ted_talks_iwslt
# 6.79e-06 - lm_zhs_qedcorpus
# 6.69e-06 - lm_ar_wikiversity_filtered
# 6.67e-06 - lm_indic-ta_wikibooks_filtered
# 6.65e-06 - lm_indic-hi_wikiquote_filtered
# 6.33e-06 - lm_indic-te_opus100
# 6.23e-06 - lm_indic-ur_wikibooks_filtered
# 5.97e-06 - lm_indic-hi_qedcorpus
# 5.78e-06 - lm_zht_qedcorpus
# 5.67e-06 - lm_nigercongo-lg_lm_nigercongo-lg_aggregated
# 5.56e-06 - lm_vi_wikiquote_filtered
# 5.35e-06 - lm_ca_teca
# 4.90e-06 - lm_id_indonli
# 4.63e-06 - lm_indic-ur_ted_talks_iwslt
# 4.41e-06 - lm_nigercongo-wo_lm_nigercongo-wo_aggregated
# 4.28e-06 - lm_indic-bn_bangla_sentiment_classification_datasets
# 4.03e-06 - lm_indic-ml_wikiquote_filtered
# 4.02e-06 - lm_nigercongo-rn_lm_nigercongo-rn_aggregated
# 3.88e-06 - lm_indic-ta_open_subtitles
# 3.66e-06 - lm_indic-mr_wikibooks_filtered
# 3.55e-06 - lm_ca_enriched_conllu_ancora_for_ml_training
# 3.49e-06 - lm_indic-bn_wikibooks_filtered
# 3.49e-06 - lm_ca_wikimedia_filtered
# 3.48e-06 - lm_en_scielo
# 3.19e-06 - lm_ca_viquiquad
# 3.11e-06 - lm_id_wikiquote_filtered
# 3.02e-06 - lm_ca_vilaquad
# 2.81e-06 - lm_indic-mr_opus100
# 2.78e-06 - lm_indic-ur_open_subtitles
# 2.75e-06 - lm_indic-ml_ted_talks_iwslt
# 2.73e-06 - lm_indic-gu_wikiquote_filtered
# 2.71e-06 - lm_indic-mr_wiktionary_filtered
# 2.63e-06 - lm_indic-hi_wikivoyage_filtered
# 2.59e-06 - lm_indic-te_open_subtitles
# 2.50e-06 - lm_fr_bloom
# 2.47e-06 - lm_nigercongo-fon_lm_nigercongo-fon_aggregated
# 2.46e-06 - lm_indic-ml_wikibooks_filtered
# 2.45e-06 - lm_indic-ta_mkb
# 2.42e-06 - lm_es_bloom
# 2.42e-06 - lm_nigercongo-nso_lm_nigercongo-nso_aggregated
# 2.28e-06 - lm_indic-te_wikiquote_filtered
# 2.09e-06 - lm_vi_vietnamese_students_feedback
# 2.08e-06 - lm_pt_wikimedia_filtered
# 2.04e-06 - lm_nigercongo-ln_lm_nigercongo-ln_aggregated
# 2.04e-06 - lm_indic-gu_ted_talks_iwslt
# 2.00e-06 - lm_indic-gu_mkb
# 1.97e-06 - lm_indic-gu_wiktionary_filtered
# 1.94e-06 - lm_indic-te_ted_talks_iwslt
# 1.94e-06 - lm_eu_ted_talks_iwslt
# 1.92e-06 - lm_nigercongo-tn_lm_nigercongo-tn_aggregated
# 1.88e-06 - lm_indic-mr_mkb
# 1.88e-06 - lm_indic-ml_mkb
# 1.83e-06 - lm_indic-kn_opus100
# 1.81e-06 - lm_indic-kn_wikiquote_filtered
# 1.74e-06 - lm_indic-bn_mkb
# 1.67e-06 - lm_indic-hi_wikiversity_filtered
# 1.62e-06 - lm_indic-or_opus100
# 1.60e-06 - lm_indic-hi_mkb
# 1.58e-06 - lm_indic-te_mkb
# 1.55e-06 - lm_nigercongo-tw_lm_nigercongo-tw_aggregated
# 1.50e-06 - lm_indic-kn_ted_talks_iwslt
# 1.49e-06 - lm_nigercongo-ny_lm_nigercongo-ny_aggregated
# 1.22e-06 - lm_ar_multilingual_knowledge_questions_answers
# 1.21e-06 - lm_indic-bn_bloom
# 1.13e-06 - lm_indic-ur_wikiquote_filtered
# 1.07e-06 - lm_vi_multilingual_knowledge_questions_answers
# 1.02e-06 - lm_fr_multilingual_knowledge_questions_answers
# 1.01e-06 - lm_es_multilingual_knowledge_questions_answers
# 9.77e-07 - lm_eu_wikiquote_filtered
# 9.64e-07 - lm_pt_multilingual_knowledge_questions_answers
# 9.43e-07 - lm_nigercongo-st_lm_nigercongo-st_aggregated
# 9.27e-07 - lm_en_multilingual_knowledge_questions_answers
# 9.07e-07 - lm_nigercongo-ts_lm_nigercongo-ts_aggregated
# 8.99e-07 - lm_ca_sts_ca
# 8.73e-07 - lm_zh-CN_multilingual_knowledge_questions_answers
# 8.53e-07 - lm_zh-TW_multilingual_knowledge_questions_answers
# 8.42e-07 - lm_zh-HK_multilingual_knowledge_questions_answers
# 8.38e-07 - lm_nigercongo-ak_lm_nigercongo-ak_aggregated
# 8.25e-07 - lm_indic-mr_wikiquote_filtered
# 6.81e-07 - lm_pt_bloom
# 6.77e-07 - lm_vi_uit_vsmec
# 5.93e-07 - lm_id_bloom
# 4.82e-07 - lm_nigercongo-bm_lm_nigercongo-bm_aggregated
# 4.53e-07 - lm_nigercongo-ki_lm_nigercongo-ki_aggregated
# 2.70e-07 - lm_ca_xquad_ca
# 2.45e-07 - lm_indic-pa_wikibooks_filtered
# 2.37e-07 - lm_indic-or_mkb
# 2.24e-07 - lm_nigercongo-tum_lm_nigercongo-tum_aggregated
# 2.20e-07 - lm_indic-ur_mkb
# 1.83e-07 - lm_id_indonesian_frog_storytelling_corpus
# 1.21e-07 - lm_indic-hi_bloom
# 1.21e-07 - lm_indic-hi_wikimedia_filtered
# 1.10e-07 - lm_en_book_dash_books
# 6.60e-08 - lm_indic-ml_bloom
# 6.47e-08 - lm_indic-ta_bloom
# 3.59e-08 - lm_indic-mr_bloom
# 2.55e-08 - lm_indic-as_ted_talks_iwslt
# 2.54e-08 - lm_fr_book_dash_books
# 2.01e-08 - lm_indic-gu_bloom
# 1.52e-08 - lm_indic-pa_bloom
# 1.51e-08 - lm_vi_bloom
# 1.38e-08 - lm_indic-ur_bloom
# 5.22e-09 - lm_indic-as_wiktionary_filtered
# 3.98e-09 - lm_indic-or_bloom
# 3.30e-09 - lm_indic-pa_ted_talks_iwslt
# 1.84e-09 - lm_zh_bloom
# 1.22e-09 - lm_indic-kn_bloom
# 4.55e-10 - lm_indic-te_bloom

# %%
import json
json.dump(tokenization_ratios, open("bigscience_tokenization_ratios_alpha_30GB.json", "w", encoding="utf-8"), indent=2)

# %%
tokenization_ratios = []

total_size = 0

for lang, sizes in lang_to_sizes.items():
    ln_target_size = lang_to_target_alphas[lang]
    current_size = 0
    prev_size = 0
    num_dsets = len(sizes)
    for i, (name, size) in enumerate(sorted(sizes, key=lambda x:x[1])):
        if current_size < ln_target_size:
            add_size = min(size - prev_size, (ln_target_size - current_size) // (num_dsets - i) + 1)
            current_size += add_size * (num_dsets - i)
            prev_size += add_size
        tokenization_ratios += [
            {
                'dataset_path': f"bigscience-catalogue-lm-data/lm_{lang}_{name}",
                'is_catalogue': True,
                'ratio': prev_size / size
            }]
    total_size += current_size

for dct in sorted(tokenization_ratios, key=lambda dct: dct['ratio'], reverse=True):
    print(f"{dct['ratio']:.2e} - {dct['dataset_path'].split('/')[1]}")
# Out:
# 1.00e+00 - lm_ar_multilingual_knowledge_questions_answers
# 1.00e+00 - lm_ar_wikiversity_filtered
# 1.00e+00 - lm_ar_arabench
# 1.00e+00 - lm_ar_qedcorpus
# 1.00e+00 - lm_ar_wikiquote_filtered
# 1.00e+00 - lm_ar_wikibooks_filtered
# 1.00e+00 - lm_ar_habibi
# 1.00e+00 - lm_ar_wikinews_filtered
# 1.00e+00 - lm_ar_labr
# 1.00e+00 - lm_ar_wiktionary_filtered
# 1.00e+00 - lm_ca_xquad_ca
# 1.00e+00 - lm_ca_sts_ca
# 1.00e+00 - lm_ca_vilaquad
# 1.00e+00 - lm_ca_viquiquad
# 1.00e+00 - lm_ca_wikimedia_filtered
# 1.00e+00 - lm_ca_enriched_conllu_ancora_for_ml_training
# 1.00e+00 - lm_ca_teca
# 1.00e+00 - lm_ca_wikiquote_filtered
# 1.00e+00 - lm_ca_ted_talks_iwslt
# 1.00e+00 - lm_ca_wikibooks_filtered
# 1.00e+00 - lm_ca_wikinews_filtered
# 1.00e+00 - lm_ca_open_subtitles
# 1.00e+00 - lm_ca_tv3_parla
# 1.00e+00 - lm_ca_opus100
# 1.00e+00 - lm_ca_parlament_parla
# 1.00e+00 - lm_ca_ca_text_corpus
# 1.00e+00 - lm_ca_wikisource_filtered
# 1.00e+00 - lm_en_book_dash_books
# 1.00e+00 - lm_en_multilingual_knowledge_questions_answers
# 1.00e+00 - lm_en_scielo
# 1.00e+00 - lm_en_odiencorp
# 1.00e+00 - lm_en_bloom
# 1.00e+00 - lm_en_ted_talks_iwslt
# 1.00e+00 - lm_en_a_million_news_headlines_abc_australia
# 1.00e+00 - lm_es_multilingual_knowledge_questions_answers
# 1.00e+00 - lm_es_bloom
# 1.00e+00 - lm_eu_wikiquote_filtered
# 1.00e+00 - lm_eu_ted_talks_iwslt
# 1.00e+00 - lm_eu_wikibooks_filtered
# 1.00e+00 - lm_eu_wiktionary_filtered
# 1.00e+00 - lm_eu_open_subtitles
# 1.00e+00 - lm_eu_wikisource_filtered
# 1.00e+00 - lm_eu_opus100
# 1.00e+00 - lm_fr_book_dash_books
# 1.00e+00 - lm_fr_multilingual_knowledge_questions_answers
# 1.00e+00 - lm_fr_bloom
# 1.00e+00 - lm_fr_qedcorpus
# 1.00e+00 - lm_fr_ester
# 1.00e+00 - lm_fr_wikiquote_filtered
# 1.00e+00 - lm_fr_wikivoyage_filtered
# 1.00e+00 - lm_fr_wikinews_filtered
# 1.00e+00 - lm_fr_ted_talks_iwslt
# 1.00e+00 - lm_id_indonesian_frog_storytelling_corpus
# 1.00e+00 - lm_id_bloom
# 1.00e+00 - lm_id_wikiquote_filtered
# 1.00e+00 - lm_id_indonli
# 1.00e+00 - lm_id_recibrew
# 1.00e+00 - lm_id_wikimedia_filtered
# 1.00e+00 - lm_id_wikibooks_filtered
# 1.00e+00 - lm_id_ted_talks_iwslt
# 1.00e+00 - lm_id_opus100
# 1.00e+00 - lm_id_wikisource_filtered
# 1.00e+00 - lm_indic-as_wiktionary_filtered
# 1.00e+00 - lm_indic-as_ted_talks_iwslt
# 1.00e+00 - lm_indic-as_samanantar
# 1.00e+00 - lm_indic-as_opus100
# 1.00e+00 - lm_indic-as_wikipedia
# 1.00e+00 - lm_indic-as_wikisource_filtered
# 1.00e+00 - lm_indic-bn_bloom
# 1.00e+00 - lm_indic-bn_mkb
# 1.00e+00 - lm_indic-bn_wikibooks_filtered
# 1.00e+00 - lm_indic-bn_bangla_sentiment_classification_datasets
# 1.00e+00 - lm_indic-bn_ted_talks_iwslt
# 1.00e+00 - lm_indic-bn_wikivoyage_filtered
# 1.00e+00 - lm_indic-bn_wiktionary_filtered
# 1.00e+00 - lm_indic-bn_bengali_question_answering
# 1.00e+00 - lm_indic-bn_pib
# 1.00e+00 - lm_indic-bn_open_subtitles
# 1.00e+00 - lm_indic-gu_bloom
# 1.00e+00 - lm_indic-gu_wiktionary_filtered
# 1.00e+00 - lm_indic-gu_mkb
# 1.00e+00 - lm_indic-gu_ted_talks_iwslt
# 1.00e+00 - lm_indic-gu_wikiquote_filtered
# 1.00e+00 - lm_indic-gu_pib
# 1.00e+00 - lm_indic-gu_opus100
# 1.00e+00 - lm_indic-gu_wikipedia
# 1.00e+00 - lm_indic-hi_wikimedia_filtered
# 1.00e+00 - lm_indic-hi_bloom
# 1.00e+00 - lm_indic-hi_mkb
# 1.00e+00 - lm_indic-hi_wikiversity_filtered
# 1.00e+00 - lm_indic-hi_wikivoyage_filtered
# 1.00e+00 - lm_indic-hi_qedcorpus
# 1.00e+00 - lm_indic-hi_wikiquote_filtered
# 1.00e+00 - lm_indic-hi_open_subtitles
# 1.00e+00 - lm_indic-hi_ted_talks_iwslt
# 1.00e+00 - lm_indic-hi_wikibooks_filtered
# 1.00e+00 - lm_indic-hi_opus100
# 1.00e+00 - lm_indic-hi_wiktionary_filtered
# 1.00e+00 - lm_indic-hi_pib
# 1.00e+00 - lm_indic-kn_bloom
# 1.00e+00 - lm_indic-kn_ted_talks_iwslt
# 1.00e+00 - lm_indic-kn_wikiquote_filtered
# 1.00e+00 - lm_indic-kn_opus100
# 1.00e+00 - lm_indic-kn_wiktionary_filtered
# 1.00e+00 - lm_indic-ml_bloom
# 1.00e+00 - lm_indic-ml_mkb
# 1.00e+00 - lm_indic-ml_wikibooks_filtered
# 1.00e+00 - lm_indic-ml_ted_talks_iwslt
# 1.00e+00 - lm_indic-ml_wikiquote_filtered
# 1.00e+00 - lm_indic-ml_pib
# 1.00e+00 - lm_indic-ml_wiktionary_filtered
# 1.00e+00 - lm_indic-ml_open_subtitles
# 1.00e+00 - lm_indic-mr_bloom
# 1.00e+00 - lm_indic-mr_wikiquote_filtered
# 1.00e+00 - lm_indic-mr_mkb
# 1.00e+00 - lm_indic-mr_wiktionary_filtered
# 1.00e+00 - lm_indic-mr_opus100
# 1.00e+00 - lm_indic-mr_wikibooks_filtered
# 1.00e+00 - lm_indic-mr_ted_talks_iwslt
# 1.00e+00 - lm_indic-mr_pib
# 1.00e+00 - lm_indic-or_bloom
# 1.00e+00 - lm_indic-or_mkb
# 1.00e+00 - lm_indic-or_opus100
# 1.00e+00 - lm_indic-or_odiencorp
# 1.00e+00 - lm_indic-or_pib
# 1.00e+00 - lm_indic-or_wikisource_filtered
# 1.00e+00 - lm_indic-or_wikipedia
# 1.00e+00 - lm_indic-or_wiktionary_filtered
# 1.00e+00 - lm_indic-pa_ted_talks_iwslt
# 1.00e+00 - lm_indic-pa_bloom
# 1.00e+00 - lm_indic-pa_wikibooks_filtered
# 1.00e+00 - lm_indic-pa_opus100
# 1.00e+00 - lm_indic-pa_wiktionary_filtered
# 1.00e+00 - lm_indic-pa_pib
# 1.00e+00 - lm_indic-pa_wikisource_filtered
# 1.00e+00 - lm_indic-ta_bloom
# 1.00e+00 - lm_indic-ta_mkb
# 1.00e+00 - lm_indic-ta_open_subtitles
# 1.00e+00 - lm_indic-ta_wikibooks_filtered
# 1.00e+00 - lm_indic-ta_wikiquote_filtered
# 1.00e+00 - lm_indic-ta_ted_talks_iwslt
# 1.00e+00 - lm_indic-ta_wikinews_filtered
# 1.00e+00 - lm_indic-ta_pib
# 1.00e+00 - lm_indic-ta_opus100
# 1.00e+00 - lm_indic-te_bloom
# 1.00e+00 - lm_indic-te_mkb
# 1.00e+00 - lm_indic-te_ted_talks_iwslt
# 1.00e+00 - lm_indic-te_wikiquote_filtered
# 1.00e+00 - lm_indic-te_open_subtitles
# 1.00e+00 - lm_indic-te_opus100
# 1.00e+00 - lm_indic-te_wikibooks_filtered
# 1.00e+00 - lm_indic-te_pib
# 1.00e+00 - lm_indic-te_wiktionary_filtered
# 1.00e+00 - lm_indic-ur_bloom
# 1.00e+00 - lm_indic-ur_mkb
# 1.00e+00 - lm_indic-ur_wikiquote_filtered
# 1.00e+00 - lm_indic-ur_open_subtitles
# 1.00e+00 - lm_indic-ur_ted_talks_iwslt
# 1.00e+00 - lm_indic-ur_wikibooks_filtered
# 1.00e+00 - lm_indic-ur_wiktionary_filtered
# 1.00e+00 - lm_indic-ur_pib
# 1.00e+00 - lm_pt_bloom
# 1.00e+00 - lm_pt_multilingual_knowledge_questions_answers
# 1.00e+00 - lm_pt_wikimedia_filtered
# 1.00e+00 - lm_pt_wikivoyage_filtered
# 1.00e+00 - lm_pt_qedcorpus
# 1.00e+00 - lm_pt_wikiquote_filtered
# 1.00e+00 - lm_pt_wikiversity_filtered
# 1.00e+00 - lm_pt_wikibooks_filtered
# 1.00e+00 - lm_pt_opus100
# 1.00e+00 - lm_pt_wikinews_filtered
# 1.00e+00 - lm_vi_bloom
# 1.00e+00 - lm_vi_uit_vsmec
# 1.00e+00 - lm_vi_multilingual_knowledge_questions_answers
# 1.00e+00 - lm_vi_vietnamese_students_feedback
# 1.00e+00 - lm_vi_wikiquote_filtered
# 1.00e+00 - lm_vi_vinbigdata_asr_vlsp_2020
# 1.00e+00 - lm_vi_wikivoyage_filtered
# 1.00e+00 - lm_vi_opus100
# 1.00e+00 - lm_vi_ted_talks_iwslt
# 1.00e+00 - lm_vi_wikibooks_filtered
# 1.00e+00 - lm_vi_data_on_covid_19_news_coverage_in_vietnam
# 1.00e+00 - lm_vi_vietnamese_poetry
# 1.00e+00 - lm_zh_bloom
# 1.00e+00 - lm_zh_wikiquote_filtered
# 1.00e+00 - lm_zh_wikivoyage_filtered
# 1.00e+00 - lm_zh_wikiversity_filtered
# 1.00e+00 - lm_zh_wikibooks_filtered
# 1.00e+00 - lm_zh_wikinews_filtered
# 1.00e+00 - lm_zh_ted_talks_iwslt
# 1.00e+00 - lm_zh_opus100
# 1.00e+00 - lm_zh_project_gutenberg
# 1.00e+00 - lm_zh-CN_multilingual_knowledge_questions_answers
# 1.00e+00 - lm_zh-HK_multilingual_knowledge_questions_answers
# 1.00e+00 - lm_zh-TW_multilingual_knowledge_questions_answers
# 1.00e+00 - lm_zhs_qedcorpus
# 1.00e+00 - lm_zht_qedcorpus
# 1.00e+00 - lm_nigercongo-sw_lm_nigercongo-sw_aggregated
# 1.00e+00 - lm_nigercongo-yo_lm_nigercongo-yo_aggregated
# 1.00e+00 - lm_nigercongo-rw_lm_nigercongo-rw_aggregated
# 1.00e+00 - lm_nigercongo-xh_lm_nigercongo-xh_aggregated
# 1.00e+00 - lm_nigercongo-ig_lm_nigercongo-ig_aggregated
# 1.00e+00 - lm_nigercongo-zu_lm_nigercongo-zu_aggregated
# 1.00e+00 - lm_nigercongo-sn_lm_nigercongo-sn_aggregated
# 1.00e+00 - lm_nigercongo-lg_lm_nigercongo-lg_aggregated
# 1.00e+00 - lm_nigercongo-wo_lm_nigercongo-wo_aggregated
# 1.00e+00 - lm_nigercongo-rn_lm_nigercongo-rn_aggregated
# 1.00e+00 - lm_nigercongo-fon_lm_nigercongo-fon_aggregated
# 1.00e+00 - lm_nigercongo-nso_lm_nigercongo-nso_aggregated
# 1.00e+00 - lm_nigercongo-ln_lm_nigercongo-ln_aggregated
# 1.00e+00 - lm_nigercongo-tn_lm_nigercongo-tn_aggregated
# 1.00e+00 - lm_nigercongo-tw_lm_nigercongo-tw_aggregated
# 1.00e+00 - lm_nigercongo-ny_lm_nigercongo-ny_aggregated
# 1.00e+00 - lm_nigercongo-st_lm_nigercongo-st_aggregated
# 1.00e+00 - lm_nigercongo-ts_lm_nigercongo-ts_aggregated
# 1.00e+00 - lm_nigercongo-ak_lm_nigercongo-ak_aggregated
# 1.00e+00 - lm_nigercongo-bm_lm_nigercongo-bm_aggregated
# 1.00e+00 - lm_nigercongo-ki_lm_nigercongo-ki_aggregated
# 1.00e+00 - lm_nigercongo-tum_lm_nigercongo-tum_aggregated
# 9.81e-01 - lm_indic-pa_wikipedia
# 9.58e-01 - lm_en_wikinews_filtered
# 9.41e-01 - lm_indic-bn_opus100
# 9.38e-01 - lm_pt_project_gutenberg
# 9.21e-01 - lm_fr_opus100
# 9.21e-01 - lm_ar_opus100
# 9.16e-01 - lm_pt_ted_talks_iwslt
# 9.13e-01 - lm_ar_ted_talks_iwslt
# 9.01e-01 - lm_ar_kalimat
# 8.90e-01 - lm_indic-ml_opus100
# 8.39e-01 - lm_vi_wiktionary_filtered
# 8.28e-01 - lm_indic-or_samanantar
# 7.71e-01 - lm_fr_wikiversity_filtered
# 7.25e-01 - lm_indic-ur_opus100
# 7.04e-01 - lm_es_wikiversity_filtered
# 6.85e-01 - lm_fr_wikibooks_filtered
# 6.80e-01 - lm_indic-gu_wikisource_filtered
# 6.79e-01 - lm_es_wikiquote_filtered
# 6.78e-01 - lm_indic-mr_wikipedia
# 6.77e-01 - lm_vi_wikisource_filtered
# 6.48e-01 - lm_es_scielo
# 6.24e-01 - lm_indic-ta_wiktionary_filtered
# 5.81e-01 - lm_id_indosum
# 5.81e-01 - lm_en_qedcorpus
# 5.73e-01 - lm_pt_wiktionary_filtered
# 5.70e-01 - lm_id_pseudocrawl-filtered_512_kumparan_com
# 5.38e-01 - lm_ca_wiktionary_filtered
# 5.29e-01 - lm_es_qedcorpus
# 5.23e-01 - lm_vi_open_subtitles
# 5.07e-01 - lm_id_indonesian_news_corpus
# 4.87e-01 - lm_zh-cn_wikipedia
# 4.86e-01 - lm_zh-tw_wikipedia
# 4.76e-01 - lm_en_india_news_headlines_dataset
# 4.68e-01 - lm_indic-kn_wikipedia
# 4.56e-01 - lm_id_wiktionary_filtered
# 4.55e-01 - lm_indic-mr_wikisource_filtered
# 4.50e-01 - lm_ca_catalan_government_crawling
# 4.29e-01 - lm_zh_wiktionary_filtered
# 4.28e-01 - lm_es_wikinews_filtered
# 4.23e-01 - lm_vi_vntq_corpus_big
# 4.01e-01 - lm_eu_wikipedia
# 3.93e-01 - lm_indic-gu_samanantar
# 3.86e-01 - lm_id_pseudocrawl-filtered_545_www_detik_com
# 3.80e-01 - lm_indic-ur_wikipedia
# 3.78e-01 - lm_indic-kn_wikisource_filtered
# 3.71e-01 - lm_pt_wikisource_filtered
# 3.69e-01 - lm_id_wikipedia
# 3.60e-01 - lm_ca_tecla
# 3.59e-01 - lm_ar_osac
# 3.43e-01 - lm_indic-ml_wikisource_filtered
# 3.39e-01 - lm_es_wikivoyage_filtered
# 3.12e-01 - lm_indic-pa_samanantar
# 3.10e-01 - lm_indic-ml_wikipedia
# 3.10e-01 - lm_vi_vinbigdata_mt_vlsp_2020
# 3.08e-01 - lm_indic-mr_samanantar
# 3.02e-01 - lm_en_wikivoyage_filtered
# 2.87e-01 - lm_indic-hi_wikipedia
# 2.85e-01 - lm_indic-kn_samanantar
# 2.85e-01 - lm_pt_the_pile_europarl
# 2.70e-01 - lm_indic-te_wikisource_filtered
# 2.64e-01 - lm_fr_the_pile_europarl
# 2.63e-01 - lm_en_wikiversity_filtered
# 2.58e-01 - lm_zh_open_subtitles
# 2.49e-01 - lm_indic-hi_wikisource_filtered
# 2.49e-01 - lm_indic-te_wikipedia
# 2.40e-01 - lm_en_the_pile_europarl
# 2.28e-01 - lm_indic-te_samanantar
# 2.22e-01 - lm_id_pseudocrawl-filtered_549_www_cnnindonesia_com
# 2.20e-01 - lm_indic-bn_wikipedia
# 2.20e-01 - lm_es_ted_talks_iwslt
# 2.19e-01 - lm_vi_wikipedia
# 2.19e-01 - lm_indic-ta_wikipedia
# 2.15e-01 - lm_ar_brad_2
# 2.09e-01 - lm_pt_scielo
# 2.08e-01 - lm_es_opus100
# 2.01e-01 - lm_indic-ta_samanantar
# 1.99e-01 - lm_en_royal_society_corpus
# 1.99e-01 - lm_en_wikiquote_filtered
# 1.99e-01 - lm_fr_pseudocrawl-filtered_599_fr_globalvoices_org
# 1.97e-01 - lm_indic-bn_samanantar
# 1.93e-01 - lm_id_pseudocrawl-filtered_572_tirto_id
# 1.90e-01 - lm_indic-ur_leipzig_wortschatz_urdu_newscrawl_2016_sentences
# 1.86e-01 - lm_ar_ksucca
# 1.78e-01 - lm_eu_bsbasque
# 1.74e-01 - lm_indic-ne_unsupervised_cross_lingual_representation_learning_at_scale
# 1.68e-01 - lm_zh_multi_un_2
# 1.65e-01 - lm_id_open_subtitles
# 1.54e-01 - lm_indic-ml_samanantar
# 1.54e-01 - lm_indic-ur_urdu-monolingual-corpus
# 1.48e-01 - lm_vi_vietai_sat
# 1.47e-01 - lm_ar_sanad
# 1.44e-01 - lm_es_wikibooks_filtered
# 1.44e-01 - lm_id_indonesian_news_articles_2017
# 1.36e-01 - lm_indic-or_indic_nlp_corpus
# 1.24e-01 - lm_fr_pseudocrawl-filtered_530_www_mediapart_fr
# 1.16e-01 - lm_fr_bnl_historical_newspapers
# 1.15e-01 - lm_en_wikibooks_filtered
# 1.09e-01 - lm_indic-bn_indic_nlp_corpus
# 1.01e-01 - lm_zh_uncorpus
# 9.45e-02 - lm_pt_wikipedia
# 8.98e-02 - lm_indic-ta_wikisource_filtered
# 8.96e-02 - lm_indic-hi_samanantar
# 8.24e-02 - lm_indic-gu_indic_nlp_corpus
# 7.90e-02 - lm_ar_tashkeela
# 7.54e-02 - lm_fr_project_gutenberg
# 7.40e-02 - lm_es_pseudocrawl-filtered_244_www_df_cl
# 7.40e-02 - lm_es_pseudocrawl-filtered_62_www_lapagina_com_sv
# 7.40e-02 - lm_es_pseudocrawl-filtered_280_salamancartvaldia_es
# 7.05e-02 - lm_es_pseudocrawl-filtered_32_www_elexpresso_com
# 7.05e-02 - lm_es_pseudocrawl-filtered_30_www_radiocable_com
# 6.95e-02 - lm_indic-pa_indic_nlp_corpus
# 6.86e-02 - lm_indic-ur_leipzig_wortschatz_urdu-pk_web_2019_sentences
# 6.80e-02 - lm_ar_wikisource_filtered
# 6.78e-02 - lm_zh_du_reader
# 6.73e-02 - lm_es_pseudocrawl-filtered_158_www_diariodeleon_es
# 6.45e-02 - lm_indic-mr_indic_nlp_corpus
# 6.44e-02 - lm_es_pseudocrawl-filtered_219_www_aguasresiduales_info
# 6.44e-02 - lm_es_pseudocrawl-filtered_153_financialfood_es
# 6.44e-02 - lm_es_pseudocrawl-filtered_56_www_eluniverso_com
# 6.37e-02 - lm_ca_wikipedia
# 6.17e-02 - lm_es_pseudocrawl-filtered_207_elimpulso_com
# 6.17e-02 - lm_es_pseudocrawl-filtered_125_www_noticiasde_es
# 6.17e-02 - lm_es_pseudocrawl-filtered_420_www_retema_es
# 5.92e-02 - lm_es_pseudocrawl-filtered_374_www_talcualdigital_com
# 5.80e-02 - lm_indic-bn_wikisource_filtered
# 5.69e-02 - lm_es_pseudocrawl-filtered_182_correodelsur_com
# 5.48e-02 - lm_es_pseudocrawl-filtered_118_www_elheraldo_hn
# 5.48e-02 - lm_es_pseudocrawl-filtered_386_www_prensalibre_com
# 5.48e-02 - lm_es_pseudocrawl-filtered_233_www_dinero_com
# 5.48e-02 - lm_es_pseudocrawl-filtered_254_diario_mx
# 5.29e-02 - lm_es_pseudocrawl-filtered_294_www_laopinion_com_co
# 5.15e-02 - lm_indic-kn_indic_nlp_corpus
# 5.11e-02 - lm_es_project_gutenberg
# 4.93e-02 - lm_es_pseudocrawl-filtered_23_www_elconfidencialdigital_com
# 4.93e-02 - lm_es_pseudocrawl-filtered_286_www_nacion_com
# 4.77e-02 - lm_es_pseudocrawl-filtered_422_www_formulatv_com
# 4.77e-02 - lm_es_pseudocrawl-filtered_417_www_radiolaprimerisima_com
# 4.77e-02 - lm_es_pseudocrawl-filtered_406_www_americaeconomia_com
# 4.77e-02 - lm_es_pseudocrawl-filtered_367_elcorreoweb_es
# 4.63e-02 - lm_es_pseudocrawl-filtered_276_radio_uchile_cl
# 4.63e-02 - lm_es_pseudocrawl-filtered_231_ojo_pe
# 4.51e-02 - lm_indic-te_indic_nlp_corpus
# 4.49e-02 - lm_es_pseudocrawl-filtered_223_www_eltambor_es
# 4.35e-02 - lm_es_pseudocrawl-filtered_325_www_laprensa_hn
# 4.35e-02 - lm_es_pseudocrawl-filtered_250_www_cooperativa_cl
# 4.35e-02 - lm_es_pseudocrawl-filtered_246_www_eldiarionuevodia_com_ar
# 4.32e-02 - lm_ca_catalan_general_crawling
# 4.23e-02 - lm_es_pseudocrawl-filtered_34_www_losandes_com_ar
# 4.16e-02 - lm_es_the_pile_europarl
# 4.11e-02 - lm_es_pseudocrawl-filtered_277_www_entornointeligente_com
# 4.11e-02 - lm_es_pseudocrawl-filtered_172_www_rionegro_com_ar
# 4.11e-02 - lm_es_pseudocrawl-filtered_167_www_ambientum_com
# 4.11e-02 - lm_es_pseudocrawl-filtered_21_www_elperiodicodearagon_com
# 4.00e-02 - lm_es_pseudocrawl-filtered_116_www_latribuna_hn
# 3.94e-02 - lm_fr_wiktionary_filtered
# 3.88e-02 - lm_ar_pseudocrawl-filtered_595_mawdoo3_com
# 3.80e-02 - lm_es_pseudocrawl-filtered_53_www_expreso_ec
# 3.80e-02 - lm_es_pseudocrawl-filtered_404_www_telam_com_ar
# 3.73e-02 - lm_fr_multi_un_2
# 3.52e-02 - lm_es_pseudocrawl-filtered_315_lasillavacia_com
# 3.52e-02 - lm_es_pseudocrawl-filtered_431_www_elperiodicoextremadura_com
# 3.44e-02 - lm_es_pseudocrawl-filtered_91_www_diario26_com
# 3.42e-02 - lm_indic-ml_indic_nlp_corpus
# 3.29e-02 - lm_es_pseudocrawl-filtered_392_www_muypymes_com
# 3.29e-02 - lm_es_pseudocrawl-filtered_169_www_el_carabobeno_com
# 3.22e-02 - lm_es_pseudocrawl-filtered_320_www_paginasiete_bo
# 3.20e-02 - lm_ar_multi_un_2
# 3.15e-02 - lm_code_stackexchange
# 3.15e-02 - lm_es_pseudocrawl-filtered_90_peru_com
# 3.14e-02 - lm_en_multi_un_2
# 3.13e-02 - lm_es_wiktionary_filtered
# 3.08e-02 - lm_es_pseudocrawl-filtered_232_tn_com_ar
# 3.08e-02 - lm_es_pseudocrawl-filtered_44_ladiaria_com_uy
# 3.08e-02 - lm_es_pseudocrawl-filtered_220_www_vanguardia_com_mx
# 3.02e-02 - lm_es_pseudocrawl-filtered_130_www_elperiodicomediterraneo_com
# 3.02e-02 - lm_es_pseudocrawl-filtered_376_www_elpopular_com_ar
# 2.96e-02 - lm_es_pseudocrawl-filtered_229_www_expansion_com
# 2.96e-02 - lm_es_pseudocrawl-filtered_253_www_debate_com_mx
# 2.96e-02 - lm_fr_wikipedia
# 2.92e-02 - lm_ar_wikipedia
# 2.91e-02 - lm_vi_vinbigdata_monolingual_vlsp_2020
# 2.85e-02 - lm_es_pseudocrawl-filtered_28_www_fayerwayer_com
# 2.79e-02 - lm_es_pseudocrawl-filtered_78_www_listindiario_com
# 2.75e-02 - lm_fr_open_subtitles
# 2.74e-02 - lm_es_pseudocrawl-filtered_359_www_efeverde_com
# 2.74e-02 - lm_es_pseudocrawl-filtered_256_www_laprovincia_es
# 2.69e-02 - lm_es_pseudocrawl-filtered_226_www_ole_com_ar
# 2.69e-02 - lm_es_pseudocrawl-filtered_317_diariocorreo_pe
# 2.69e-02 - lm_es_pseudocrawl-filtered_165_www_ticbeat_com
# 2.69e-02 - lm_es_pseudocrawl-filtered_401_www_elperiodicodemexico_com
# 2.67e-02 - lm_pt_open_subtitles
# 2.51e-02 - lm_es_pseudocrawl-filtered_675_www_elespectador_com
# 2.51e-02 - lm_es_pseudocrawl-filtered_257_www_diaridetarragona_com
# 2.43e-02 - lm_es_pseudocrawl-filtered_213_www_hola_com
# 2.39e-02 - lm_es_pseudocrawl-filtered_203_www_que_es
# 2.39e-02 - lm_es_pseudocrawl-filtered_405_www_emol_com
# 2.35e-02 - lm_es_pseudocrawl-filtered_67_www_elpais_cr
# 2.31e-02 - lm_es_pseudocrawl-filtered_430_www_eldiario_ec
# 2.31e-02 - lm_es_pseudocrawl-filtered_324_gestion_pe
# 2.31e-02 - lm_ar_open_subtitles
# 2.28e-02 - lm_es_pseudocrawl-filtered_288_www_marca_com
# 2.24e-02 - lm_es_pseudocrawl-filtered_71_www_rtve_es
# 2.24e-02 - lm_es_pseudocrawl-filtered_381_www_cuartopoder_es
# 2.21e-02 - lm_es_pseudocrawl-filtered_209_misionesonline_net
# 2.12e-02 - lm_indic-ta_indic_nlp_corpus
# 2.11e-02 - lm_en_wiktionary_filtered
# 2.08e-02 - lm_es_pseudocrawl-filtered_86_www_motorpasion_com
# 2.08e-02 - lm_es_pseudocrawl-filtered_373_www_farodevigo_es
# 2.03e-02 - lm_es_pseudocrawl-filtered_287_www_cibercuba_com
# 1.99e-02 - lm_fr_pseudocrawl-filtered_550_www_lemonde_fr
# 1.97e-02 - lm_es_pseudocrawl-filtered_249_www_telecinco_es
# 1.90e-02 - lm_es_pseudocrawl-filtered_79_www_laopiniondemurcia_es
# 1.86e-02 - lm_fr_uncorpus
# 1.83e-02 - lm_es_pseudocrawl-filtered_299_www_lne_es
# 1.82e-02 - lm_indic-hi_iitb_english_hindi_corpus
# 1.80e-02 - lm_es_pseudocrawl-filtered_641_es_globalvoices_org
# 1.76e-02 - lm_en_uncorpus
# 1.74e-02 - lm_es_pseudocrawl-filtered_58_www_levante_emv_com
# 1.66e-02 - lm_es_pseudocrawl-filtered_157_www_elsoldemexico_com_mx
# 1.65e-02 - lm_ar_uncorpus
# 1.57e-02 - lm_es_pseudocrawl-filtered_237_www_cronista_com
# 1.57e-02 - lm_es_pseudocrawl-filtered_245_www_noticiasdenavarra_com
# 1.45e-02 - lm_es_pseudocrawl-filtered_518_www_elcolombiano_com
# 1.45e-02 - lm_es_pseudocrawl-filtered_248_www_telesurtv_net
# 1.42e-02 - lm_es_wikisource_filtered
# 1.42e-02 - lm_es_pseudocrawl-filtered_136_valenciaplaza_com
# 1.38e-02 - lm_en_no_code_stackexchange
# 1.25e-02 - lm_indic-hi_indic_nlp_corpus
# 1.22e-02 - lm_es_pseudocrawl-filtered_103_www_elmostrador_cl
# 1.19e-02 - lm_es_pseudocrawl-filtered_189_www_eleconomista_com_mx
# 1.19e-02 - lm_indic-bn_bangla_lm
# 1.14e-02 - lm_es_pseudocrawl-filtered_429_cadenaser_com
# 1.13e-02 - lm_es_pseudocrawl-filtered_146_www_perfil_com
# 1.07e-02 - lm_es_pseudocrawl-filtered_215_www_lainformacion_com
# 1.07e-02 - lm_ca_catalan_textual_corpus
# 1.06e-02 - lm_es_pseudocrawl-filtered_198_www_eleconomista_es
# 1.06e-02 - lm_es_pseudocrawl-filtered_409_www_proceso_com_mx
# 1.06e-02 - lm_es_pseudocrawl-filtered_263_www_lasexta_com
# 1.03e-02 - lm_es_pseudocrawl-filtered_354_www_lagaceta_com_ar
# 1.01e-02 - lm_es_pseudocrawl-filtered_181_noticiassin_com
# 9.55e-03 - lm_es_pseudocrawl-filtered_267_www_elperiodico_com_es
# 9.25e-03 - lm_es_pseudocrawl-filtered_211_www_elcomercio_com
# 8.41e-03 - lm_es_pseudocrawl-filtered_349_www_eltiempo_com
# 8.09e-03 - lm_es_pseudocrawl-filtered_333_www_elmundo_es
# 8.05e-03 - lm_en_wikipedia
# 7.73e-03 - lm_fr_wikisource_filtered
# 7.51e-03 - lm_es_pseudocrawl-filtered_255_elcomercio_pe
# 6.88e-03 - lm_es_pseudocrawl-filtered_63_www_lanacion_com_ar
# 6.76e-03 - lm_es_pseudocrawl-filtered_424_www_lavanguardia_com
# 6.44e-03 - lm_es_multi_un_2
# 6.01e-03 - lm_ar_openiti_proc
# 5.92e-03 - lm_en_open_subtitles
# 5.86e-03 - lm_code_github-no-gpl
# 5.73e-03 - lm_pt_brwac
# 5.59e-03 - lm_es_pseudocrawl-filtered_20_www_clarin_com
# 5.45e-03 - lm_es_wikipedia
# 5.40e-03 - lm_es_pseudocrawl-filtered_341_es_cointelegraph_com
# 5.06e-03 - lm_ar_arabic_billion_words
# 4.95e-03 - lm_es_pseudocrawl-filtered_396_www_eldiario_es
# 4.91e-03 - lm_ar_openiti
# 4.30e-03 - lm_es_pseudocrawl-filtered_100_www_aporrea_org
# 4.28e-03 - lm_en_project_gutenberg
# 3.62e-03 - lm_vi_binhvq_news_corpus
# 3.22e-03 - lm_en_the_pile_uspto
# 3.19e-03 - lm_es_uncorpus
# 2.48e-03 - lm_id_indo4b
# 2.09e-03 - lm_es_open_subtitles
# 1.14e-03 - lm_fr_hal_archives_ouvertes
# 1.13e-03 - lm_zh_wudaocorpora
# 6.83e-04 - lm_en_s2orc_ai2_abstracts
# 6.77e-04 - lm_en_pmc
# 4.21e-04 - lm_en_arxiv
# 2.95e-04 - lm_en_s2orc_ai2_pdf_parses

# %%
json.dump(tokenization_ratios, open("bigscience_tokenization_ratios_alpha_30GB_sampling_format.json", "w", encoding="utf-8"), indent=2)

# %%
tokenization_ratios = []

per_lang_tot = {}

total_size = 0

for lang, sizes in lang_to_sizes.items():
    target_size = min(int(1.5e11), sum([x[1] for x in sizes]))
    current_size = 0
    prev_size = 0
    num_dsets = len(sizes)
    with_samples = []
    for i, (name, size) in enumerate(sorted(sizes, key=lambda x:x[1])):
        if current_size < target_size:
            add_size = min(size - prev_size, (target_size - current_size) // (num_dsets - i) + 1)
            current_size += add_size * (num_dsets - i)
            prev_size += add_size
        with_samples += [(name, size, prev_size, prev_size/size)]
        tokenization_ratios += [
            {
                'dataset_path': f"bigscience-catalogue-lm-data/lm_{lang}_{name}",
                'is_catalogue': True,
                'ratio': prev_size / size
            }]
    total_size += current_size
    per_lang_tot[lang] = per_lang_tot.get(lang, 0) + current_size
    print(lang, f"{current_size / 1e9:.3f}")

tokenization_ratios += [{
    'dataset_path': f"bigscience-catalogue-lm-data/tokenization_nigercongo",
    'is_catalogue': True,
    'ratio': 1.
}]
per_lang_tot["nigercongo"] = 600000000


print(f"------ Total: {total_size / 1e9:.3f} GB")
tokenization_ratios

# %%
import re

id_re = re.compile(r'\b[A-Za-z]*(?:[-\.]*\d){6,}\b')

# %%
st = """
the war of 1914-18 was called the Great War
"""

print(re.sub(id_re, "<ID>", st))
# Out:
# the war of <ID> was called the Great War
